# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

pd.set_option('display.max_columns', None)
plt.style.use('default')
#sns.set_palette("husl") 
# set color to '#5F8FDC'
#sns.set_color_codes("pastel")

plt.rcParams.update({
    "font.family": "serif",      # serif to match LaTeX article style
    "font.size": 10,
    "axes.titlesize": 12,
    "axes.labelsize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
})

# create folder for figures if it doesn't exist
import os
FIGURE_DIR = "figures"
os.makedirs(FIGURE_DIR, exist_ok=True)

# %% [markdown]
# ACSConverter(
# ResNet(
#   (conv1): ACSConv(1, 64, kernel_size=(7, 7, 7), stride=(2, 2, 2), padding=(3, 3, 3), bias=False, acs_kernel_split=(22, 21, 21))
#   (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool3d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): ACSConv(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(22, 21, 21))
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): ACSConv(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(22, 21, 21))
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): ACSConv(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(22, 21, 21))
#       (bn1): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): ACSConv(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(22, 21, 21))
#       (bn2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): ACSConv(64, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False, acs_kernel_split=(43, 43, 42))
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): ACSConv(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(43, 43, 42))
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): ACSConv(64, 128, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False, acs_kernel_split=(43, 43, 42))
#         (1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): ACSConv(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(43, 43, 42))
#       (bn1): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): ACSConv(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(43, 43, 42))
#       (bn2): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): ACSConv(128, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False, acs_kernel_split=(86, 85, 85))
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): ACSConv(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(86, 85, 85))
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): ACSConv(128, 256, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False, acs_kernel_split=(86, 85, 85))
#         (1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): ACSConv(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(86, 85, 85))
#       (bn1): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): ACSConv(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(86, 85, 85))
#       (bn2): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): ACSConv(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1), bias=False, acs_kernel_split=(171, 171, 170))
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): ACSConv(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(171, 171, 170))
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): ACSConv(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False, acs_kernel_split=(171, 171, 170))
#         (1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): ACSConv(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(171, 171, 170))
#       (bn1): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): ACSConv(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False, acs_kernel_split=(171, 171, 170))
#       (bn2): BatchNorm3d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool3d(output_size=(1, 1, 1))
#   (fc): Linear(in_features=512, out_features=1, bias=True)
# )
# )

# %%
# Subplot version of the two line plots with an updated color palette
from matplotlib import cm
import numpy as np
import nibabel as nib

cases_df = pd.read_csv('collected_cases_with_depths.csv')

Patient_small = cases_df[cases_df['PercentLungSlices'] < 41]['PatientID'].tolist()
list_outlier = [1000986,1000641,1000658,1001215,1001138,1002744,1001629,1001244,1001117,1001137,1002427, 1000985,1001198, 1002407, 1000635, 1001029, 1001115]
list_outlier_corected = [pid for pid in list_outlier if pid not in [1000658, 1001138]]
intersection = set(Patient_small).intersection(set(list_outlier))
print("Number of patients with less than 45% lung slices:", len(Patient_small))
print("Outlier Patient IDs with less than 45% lung slices:", intersection)
print("Total number of outlier patients identified:", len(list_outlier))
print(f'Patients with less than 45% lung slices not in the outlier list: {set(Patient_small)-set(list_outlier)}')
print(f'Outlier patients with more than 45% lung slices: {set(list_outlier)-set(Patient_small)}')
outlier_more_than_45 = [pid for pid in list_outlier if pid not in Patient_small]
patient_small_without_outliers = [pid for pid in Patient_small if pid not in list_outlier]
outlier_and_small_df = cases_df[cases_df['PatientID'].isin(outlier_more_than_45 + patient_small_without_outliers)]

Patient_small_clean = cases_df[cases_df['PercentLungSlices'] < 60]['PatientID'].tolist()[28:35]
print(Patient_small_clean)

plt.rcParams.update({
    "font.family": "serif",      # serif to match LaTeX article style
    "font.size": 10,
    "axes.titlesize": 16,
    "axes.labelsize": 16,
    "legend.fontsize": 9,
    "xtick.labelsize": 15,
    "ytick.labelsize": 15,
})

fig, axes = plt.subplots(1, 2, figsize=(17, 6), sharey=True)

# Choose palettes
palette_left = cm.get_cmap("RdYlBu", max(len(patient_small_without_outliers), 1))
palette_right = cm.get_cmap("BrBG", max(len(Patient_small_clean), 1))

# Left subplot: patient_small_without_outliers
for i, patient_id in enumerate(patient_small_without_outliers):
    mask_nifty_path = cases_df[cases_df["PatientID"] == patient_id]["Mask"].values[0]
    mask_scan = nib.load(mask_nifty_path).get_fdata()
    non_zero_pixels_per_slice = [np.sum(mask_scan[s, :, :] > 0) for s in range(mask_scan.shape[0])]

    axes[0].plot(
        non_zero_pixels_per_slice,
        color=palette_left(i),
        linewidth=1.6,
        alpha=0.95,
        label=f"Patient {patient_id}"
    )

axes[0].set_title("Outlier Candidates")
axes[0].set_xlabel("Slice Index (Depth)")
axes[0].set_ylabel("Non-Zero Mask Pixels")
axes[0].grid(axis='y', alpha=0.25, linestyle="--")
axes[0].legend(loc="upper right", fontsize=8, frameon=True)

# Right subplot: Patient_small_clean
for i, patient_id in enumerate(Patient_small_clean):
    mask_nifty_path = cases_df[cases_df["PatientID"] == patient_id]["Mask"].values[0]
    mask_scan = nib.load(mask_nifty_path).get_fdata()
    non_zero_pixels_per_slice = [np.sum(mask_scan[s, :, :] > 0) for s in range(mask_scan.shape[0])]

    axes[1].plot(
        non_zero_pixels_per_slice,
        color=palette_right(i),
        linewidth=1.6,
        alpha=0.95,
        label=f"Patient {patient_id}"
    )

axes[1].set_title("Clean Lung-Coverage")
axes[1].set_xlabel("Slice Index (Depth)")
axes[1].grid(axis='y', alpha=0.25, linestyle="--")
axes[1].legend(loc="upper right", fontsize=8, frameon=True)

#plt.suptitle("Non-Zero Mask Pixels Across Depth: Two Patient Groups", y=1.02)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, "non_zero_mask_pixels_by_depth_comparison.png"), dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/OSIC_Analysis/.venv/lib64/python3.9/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PercentLungSlices'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 8
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
crf_df = pd.read_csv('../../../scratch/bds/OSIC/Merge_CRF_fill.csv')
dicom_df = pd.read_csv('../../../scratch/bds/OSIC/DICOM_file_all.csv')

dicom_df['Acquisition Date']= dicom_df['Acquisition Date'].dropna().astype(int).astype(str)


dicom_df['Acquisition Date'] = pd.to_datetime(dicom_df['Acquisition Date'], errors='coerce')
dicom_df[['Patient ID','Acquisition Date']].sort_values(by=['Patient ID'])

crf_df = crf_df[crf_df['FVC Volume L'].notna()]
crf_df.sort_values(by=['Subject ID'])[['Subject ID', 'FVC DATE', 'FVC Volume L']]
#delete duplicates
crf_df = crf_df.drop_duplicates(subset=['Subject ID', 'FVC DATE'])


crf_FVC_pred = crf_df.sort_values(by=['Subject ID'])[['Subject ID', 'FVC DATE', 'FVC Volume L', 'Primary Diagnosis', 'Sex', 'FVC Predicted %']]

crf_FVC_pred['FVC DATE'] = pd.to_datetime(crf_FVC_pred['FVC DATE'], errors='coerce')


# create column with week of FVC measurement per patient since first FVC measurement
crf_FVC_pred['FVC Week'] = (crf_FVC_pred['FVC DATE'] - crf_FVC_pred.groupby('Subject ID')['FVC DATE'].transform('min')).dt.days // 7

followup_patients = crf_FVC_pred[crf_FVC_pred['Subject ID'].map(crf_FVC_pred['Subject ID'].value_counts()) >= 2]
followup_patients = followup_patients.sort_values(by=['Subject ID'])
followup_patients['FVC DATE'] = pd.to_datetime(followup_patients['FVC DATE'], errors='coerce')

followup_patients['FVC DATE'] = pd.to_datetime(followup_patients['FVC DATE'], errors='coerce')
followup_patients[['Subject ID','FVC DATE']].sort_values(by=['Subject ID'])

patient_common_dates =[]
for patient in set(followup_patients['Subject ID']):
    dicom_patient_data = dicom_df[dicom_df['Patient ID'] == patient]
    list_dicom_dates = dicom_patient_data['Acquisition Date'].tolist()
    # Create list of dicom dates +/- 7 days
    list_dicom_dates_plus_minus = []
    for date in list_dicom_dates:
        list_dicom_dates_plus_minus.extend([date + pd.DateOffset(days=day) for day in range(-14, 15)])
    list_crf_dates = followup_patients[followup_patients['Subject ID'] == patient]['FVC DATE'].tolist()

    # Find common dates
    #TODO: + - one week difference 

    common_dates = set(list_dicom_dates) & set(list_crf_dates)
    common_dates_plus_minus = set(list_dicom_dates_plus_minus) & set(list_crf_dates)



    if len(common_dates_plus_minus) > 0:
        if min(common_dates_plus_minus) < max(list_crf_dates):
            patient_common_dates.append(patient)


followup_with_dicom_dates = followup_patients[followup_patients['Subject ID'].isin(patient_common_dates)]

for patient in followup_with_dicom_dates['Subject ID'].unique():
    dicom_patient_data = dicom_df[dicom_df['Patient ID'] == patient]
    acquisition_dates = dicom_patient_data['Acquisition Date'].unique()
    first_acquisition_date = acquisition_dates.min() if acquisition_dates.size > 0 else None
    #save the first acquisition date
    followup_with_dicom_dates.loc[followup_with_dicom_dates['Subject ID'] == patient, 'First Acquisition Date'] = first_acquisition_date

followup_with_dicom_dates['Week FVC First Acquisition'] = (
    (followup_with_dicom_dates['FVC DATE'] - followup_with_dicom_dates['First Acquisition Date']).dt.days // 7
)
# Out:
# /tmp/ipykernel_4010109/535756758.py:3: DtypeWarning: Columns (99) have mixed types. Specify dtype option on import or set low_memory=False.
#   crf_df = pd.read_csv('../../../scratch/bds/OSIC/Merge_CRF_fill.csv')
# /tmp/ipykernel_4010109/535756758.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   followup_with_dicom_dates.loc[followup_with_dicom_dates['Subject ID'] == patient, 'First Acquisition Date'] = first_acquisition_date
# /tmp/ipykernel_4010109/535756758.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#followup_with_dicom_dates[followup_with_dicom_dates['Week FVC First Acquisition'] > 100]

# Global style
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 15,
    "axes.titlesize": 16,
    "axes.labelsize": 16,
    "legend.fontsize": 12,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
})

fig, axes = plt.subplots(1, 2, figsize=(17, 6))

# --- Left subplot: relative to first HRCT ---
sns.histplot(
    data=followup_with_dicom_dates,
    x='Week FVC First Acquisition',
    bins=300,
    color='#4C72B0',
    edgecolor='black',
    ax=axes[0]
)

axes[0].set_xlabel('Time Relative to First HRCT [weeks]')
axes[0].set_ylabel('Frequency')
axes[0].axvline(0, color='red', linestyle='--', linewidth=1, label='First HRCT (week 0)')
axes[0].set_xlim(-20, 165)
axes[0].set_ylim(0, 450)
axes[0].tick_params(axis='x', rotation=45)
axes[0].grid(axis='y', alpha=0.4, linestyle='--')
axes[0].legend(frameon=True)

# --- Right subplot: relative to first FVC ---
sns.histplot(
    data=crf_FVC_pred,
    x='FVC Week',
    bins=300,
    color='#4C72B0',
    edgecolor='black',
    ax=axes[1]
)

axes[1].set_xlabel('Time Relative to FVC Measurement [weeks]')
axes[1].set_ylabel('Frequency')
axes[1].axvline(0, color='red', linestyle='-', linewidth=1, label='Baseline (week 0)')
axes[1].axvline(52, color='green', linestyle='-', linewidth=1.5, label='Target follow-up (week 52)')
axes[1].axvline(48, color='green', linestyle='--', linewidth=1, alpha=0.8, label='Week 52 ± 4')
axes[1].axvline(56, color='green', linestyle='--', linewidth=1, alpha=0.8)
axes[1].axvspan(48, 56, color='green', alpha=0.12)
axes[1].set_xlim(-20, 165)
axes[1].set_ylim(0, 450)
axes[1].tick_params(axis='x', rotation=45)
axes[1].grid(axis='y', alpha=0.4, linestyle='--')
axes[1].legend(frameon=True)

# # Titles under each subplot with (a), (b)
# axes[0].text(
#     0.5, -0.28,
#     '(a) Timing of FVC Measurements Relative to First HRCT',
#     transform=axes[0].transAxes, ha='center', va='top'
# )
# axes[1].text(
#     0.5, -0.28,
#     '(b) Timing of FVC Measurements Relative to First FVC Measurement',
#     transform=axes[1].transAxes, ha='center', va='top'
# )

plt.tight_layout()
plt.subplots_adjust(bottom=0.25)  # extra space for bottom titles
plt.savefig(os.path.join(FIGURE_DIR, 'osfvc_distributions_combined.pdf'), dpi=300, bbox_inches='tight')
# plt.savefig(os.path.join(FIGURE_DIR, 'fvc_distributions_combined.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
#followup_with_dicom_dates[followup_with_dicom_dates['Week FVC First Acquisition'] > 100]

# Global style
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 15,
    "axes.titlesize": 12,
    "axes.labelsize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
})

fig, axes = plt.subplots(2, 1, figsize=(10, 14))

# --- Left subplot: relative to first HRCT ---
sns.histplot(
    data=followup_with_dicom_dates,
    x='Week FVC First Acquisition',
    bins=300,
    color='#4C72B0',
    edgecolor='black',
    ax=axes[0]
)

axes[0].set_xlabel('Time Relative to First HRCT [weeks]')
axes[0].set_ylabel('Frequency')
axes[0].axvline(0, color='red', linestyle='--', linewidth=1, label='First HRCT (week 0)')
axes[0].set_xlim(-20, 165)
axes[0].set_ylim(0, 450)
axes[0].tick_params(axis='x', rotation=45)
axes[0].grid(axis='y', alpha=0.4, linestyle='--')
axes[0].legend(frameon=True)

# --- Right subplot: relative to first FVC ---
sns.histplot(
    data=crf_FVC_pred,
    x='FVC Week',
    bins=300,
    color='#4C72B0',
    edgecolor='black',
    ax=axes[1]
)

axes[1].set_xlabel('Time Relative to FVC Measurement [weeks]')
axes[1].set_ylabel('Frequency')
axes[1].axvline(0, color='red', linestyle='-', linewidth=1, label='Baseline (week 0)')
axes[1].axvline(52, color='green', linestyle='-', linewidth=1.5, label='Target follow-up (week 52)')
axes[1].axvline(48, color='green', linestyle='--', linewidth=1, alpha=0.8, label='Week 52 ± 4')
axes[1].axvline(56, color='green', linestyle='--', linewidth=1, alpha=0.8)
axes[1].axvspan(48, 56, color='green', alpha=0.12)
axes[1].set_xlim(-20, 165)
axes[1].set_ylim(0, 450)
axes[1].tick_params(axis='x', rotation=45)
axes[1].grid(axis='y', alpha=0.4, linestyle='--')
axes[1].legend(frameon=True)

# # Titles under each subplot with (a), (b)
# axes[0].text(
#     0.5, -0.28,
#     '(a) Timing of FVC Measurements Relative to First HRCT',
#     transform=axes[0].transAxes, ha='center', va='top'
# )
# axes[1].text(
#     0.5, -0.28,
#     '(b) Timing of FVC Measurements Relative to First FVC Measurement',
#     transform=axes[1].transAxes, ha='center', va='top'
# )

plt.tight_layout()
plt.subplots_adjust(bottom=0.25)  # extra space for bottom titles
plt.savefig('fvc_distributions_combined.pdf', dpi=300, bbox_inches='tight')
# plt.savefig('fvc_distributions_combined.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# **Figure caption**
#
#
#
# Distribution of FVC measurement timings relative to (a) the first HRCT scan and (b) the first available FVC assessment. Patients shown in panel (a) were filtered to retain only those with at least one FVC measurement having a common DICOM date, defined here as an FVC date occurring within $\pm 14$ days of a recorded HRCT acquisition date; in addition, at least one such matched FVC date had to occur before the patient's last available FVC assessment. In panel (a), the vertical red dashed line denotes the week of the first HRCT scan (week 0). In panel (b), the red line marks the baseline FVC measurement (week 0), the solid green line indicates the target follow-up at week 52, and the dashed green lines represent the allowable visit window of week $52 \pm 4$. Histograms illustrate the frequency of recorded FVC measurements across all patients within the respective time windows.

# %%
followup_with_dicom_dates['Subject ID'].nunique()
# Out:
# 1682

# %%
cases_df = pd.read_csv('cleaned_collected_cases_final_with_FEV1.csv')
cases_df.head()

print(f"Number of unique patients: {cases_df['PatientID'].nunique()}")
# Out:
# Number of unique patients: 556

# %%
cases_df_old = pd.read_csv('cleaned_collected_cases_with_followup_and_age.csv')
cases_df_old.head()

print(f"Number of unique patients: {cases_df_old['PatientID'].nunique()}")
print(f"Number of missing in age: {cases_df_old['Age'].isna().sum()}")

filter_by_patient_id = cases_df_old['PatientID'].isin(cases_df['PatientID'])
cases_df_old_filtered = cases_df_old[filter_by_patient_id]

print(f"Number of unique patients in filtered old dataset: {cases_df_old_filtered['PatientID'].nunique()}") 
print(f"Number of missing in age after filtering: {cases_df_old_filtered['Age'].isna().sum()}") 
print(f"Percentage of missing in age after filtering: {cases_df_old_filtered['Age'].isna().mean() * 100:.2f}%")

print(f"Percent of missing in FEV1 in the new dataset: {cases_df['FEV1 Volume L'].isna().mean() * 100:.2f}%")
# Out:
# Number of unique patients: 556
# Number of missing in age: 151
# Number of unique patients in filtered old dataset: 556
# Number of missing in age after filtering: 151
# Percentage of missing in age after filtering: 27.16%
# Percent of missing in FEV1 in the new dataset: 1.62%

# %%
demographics_df = cases_df[['PatientID','Age','Primary Diagnosis','Sex','Smoking History','FEV1 Volume L','Baseline FVC Volume L', 'Followup FVC Volume L', 'Delta FVC']]

# %%
# Statistics of demographics
print("Demographics Statistics:")
print(demographics_df.describe())   
# statistic categorical variables
print("\nCategorical Variables:")
print(demographics_df['Primary Diagnosis'].value_counts())
print("\nSex Distribution:")
print(demographics_df['Sex'].value_counts())
print("\nSmoking History Distribution:")
print(demographics_df['Smoking History'].value_counts())
# Out:
# Demographics Statistics:
#           PatientID         Age  FEV1 Volume L  Baseline FVC Volume L  \
# count  5.560000e+02  556.000000     547.000000             556.000000
# mean   7.940485e+05   65.955446       2.043053               2.561394
# std    2.809247e+05   10.407308       0.644007               0.842366
# min    1.009220e+05   19.000000       0.500000               0.940000
# 25%    6.047340e+05   64.000000       1.575000               1.935250
# 50%    1.000461e+06   65.955446       2.000000               2.470000
# 75%    1.000978e+06   72.000000       2.470000               3.072500
# max    1.007005e+06   87.000000       4.300000               5.690000
#
#        Followup FVC Volume L   Delta FVC
# count             556.000000  556.000000
# mean                2.489563   -0.071831
# std                 0.873221    0.374108
# min                 0.680000   -2.110000
# 25%                 1.835000   -0.240000
# 50%                 2.410000   -0.080000
# ...

# %%
# For each categorical variable value, give the sex ratio and mean of delta FVC
print("\nSex Ratio and Mean Delta FVC by Primary Diagnosis:")
for diagnosis in demographics_df['Primary Diagnosis'].unique():
    subset = demographics_df[demographics_df['Primary Diagnosis'] == diagnosis]
    sex_ratio = subset['Sex'].value_counts(normalize=True).to_dict()
    mean_delta_fvc = subset['Delta FVC'].mean()
    median_fvc = subset['Delta FVC'].median()
    age_mean = subset['Age'].mean()
    print(f"Diagnosis: {diagnosis}")
    print(f"Sex Ratio: {sex_ratio}")
    print(f"Mean Delta FVC: {mean_delta_fvc}")
    print(f"Median Delta FVC: {median_fvc}")
    print(f"Mean Age: {age_mean}\n")

for smoking_status in demographics_df['Smoking History'].unique():
    subset = demographics_df[demographics_df['Smoking History'] == smoking_status]
    sex_ratio = subset['Sex'].value_counts(normalize=True).to_dict()
    mean_delta_fvc = subset['Delta FVC'].mean()
    median_fvc = subset['Delta FVC'].median()
    age_mean = subset['Age'].mean()
    print(f"Smoking History: {smoking_status}")
    print(f"Sex Ratio: {sex_ratio}")
    print(f"Mean Delta FVC: {mean_delta_fvc}")
    print(f"Median Delta FVC: {median_fvc}")
    print(f"Mean Age: {age_mean}\n")

for sex in demographics_df['Sex'].unique():
    subset = demographics_df[demographics_df['Sex'] == sex]
    mean_delta_fvc = subset['Delta FVC'].mean()
    median_fvc = subset['Delta FVC'].median()
    age_mean = subset['Age'].mean()
    print(f"Sex: {sex}")
    print(f"Mean Delta FVC: {mean_delta_fvc}")
    print(f"Median Delta FVC: {median_fvc}")
    print(f"Mean Age: {age_mean}\n")
# Out:
# Sex Ratio and Mean Delta FVC by Primary Diagnosis:
# Diagnosis: CTD-ILD
# Sex Ratio: {'Female': 0.6833333333333333, 'Male': 0.31666666666666665}
# Mean Delta FVC: -0.03360555555555552
# Median Delta FVC: -0.04
# Mean Age: 62.70393289328932
#
# Diagnosis: UILD
# Sex Ratio: {'Male': 0.6385542168674698, 'Female': 0.3614457831325301}
# Mean Delta FVC: -0.10879518072289156
# Median Delta FVC: -0.0900000000000003
# Mean Age: 68.78522008827386
#
# Diagnosis: IPF
# Sex Ratio: {'Male': 0.6787330316742082, 'Female': 0.3212669683257919}
# Mean Delta FVC: -0.10949773387330314
# Median Delta FVC: -0.0899999999999998
# Mean Age: 68.23988620581514
#
# Diagnosis: Other
# Sex Ratio: {'Male': 0.5897435897435898, 'Female': 0.41025641025641024}
# Mean Delta FVC: 0.09410256410256412
# Median Delta FVC: 0.08
# Mean Age: 63.270627062706275
#
# Diagnosis: CHP
# Sex Ratio: {'Female': 0.5151515151515151, 'Male': 0.48484848484848486}
# Mean Delta FVC: -0.1312121212121212
# ...

# %%
# plot of delta FVC for Active smokers vs Non-smokers
plt.figure(figsize=(8, 6))
sns.boxplot(x='Smoking History', y='Delta FVC', data=demographics_df, palette='Set2')
plt.title('Delta FVC by Smoking History')
plt.xlabel('Smoking History')
plt.ylabel('Delta FVC [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4010109/766654644.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Smoking History', y='Delta FVC', data=demographics_df, palette='Set2')

# %%
## Plot FVC baseline against follow-up
plt.figure(figsize=(8, 8))
plt.scatter(demographics_df['Baseline FVC Volume L'], demographics_df['Followup FVC Volume L'], alpha=0.6, edgecolor='white')
plt.plot([0, 5], [0, 5], color='red', linestyle='--')  # line of equality
plt.title('Baseline vs Follow-up FVC Volumes')
plt.xlabel('Baseline FVC Volume [L]')
plt.ylabel('Follow-up FVC Volume [L]')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# plot fvc follow-up against fev1
corelation = demographics_df['Followup FVC Volume L'].corr(demographics_df['Baseline FVC Volume L'])
print(f"Correlation between Followup FVC Volume and Baseline FVC Volume: {corelation:.2f}")

# # First plot (already with regression line)
# sns.lmplot(
#     x='Followup FVC Volume L',
#     y='FEV1 Volume L',
#     data=demographics_df,
#     scatter_kws={'alpha': 0.6, 'edgecolor': 'white'}
# )

# Second plot with regression line added
plt.figure(figsize=(8, 8))
sns.regplot(
    data=demographics_df,
    x='Followup FVC Volume L',
    y='Baseline FVC Volume L',
    scatter_kws={'alpha': 0.6, 'edgecolor': 'white'},
    line_kws={'color': 'red', 'linewidth': 2}
)

plt.title('Followup FVC Volume vs Baseline FVC Volume')
plt.xlabel('Followup FVC Volume [L]')
plt.ylabel('Baseline FVC Volume [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.show()
# Out:
# Correlation between Followup FVC Volume and Baseline FVC Volume: 0.91

# %%
# plot fvc follow-up against fev1
corelation = demographics_df['Baseline FVC Volume L'].corr(demographics_df['FEV1 Volume L'])
print(f"Correlation between Baseline FVC Volume and FEV1 Volume: {corelation:.2f}")

# # First plot (already with regression line)
# sns.lmplot(
#     x='Followup FVC Volume L',
#     y='FEV1 Volume L',
#     data=demographics_df,
#     scatter_kws={'alpha': 0.6, 'edgecolor': 'white'}
# )

# Second plot with regression line added
plt.figure(figsize=(8, 8))
sns.regplot(
    data=demographics_df,
    x='Baseline FVC Volume L',
    y='FEV1 Volume L',
    scatter_kws={'alpha': 0.6, 'edgecolor': 'white'},
    line_kws={'color': 'red', 'linewidth': 2}
)

plt.title('Baseline FVC Volume vs FEV1 Volume')
plt.xlabel('Baseline FVC Volume [L]')
plt.ylabel('FEV1 Volume [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.show()
# Out:
# Correlation between Baseline FVC Volume and FEV1 Volume: 0.94

# %%
# plot fvc follow-up against fev1
corelation = demographics_df['Followup FVC Volume L'].corr(demographics_df['FEV1 Volume L'])
print(f"Correlation between Followup FVC Volume and FEV1 Volume: {corelation:.2f}")

# # First plot (already with regression line)
# sns.lmplot(
#     x='Followup FVC Volume L',
#     y='FEV1 Volume L',
#     data=demographics_df,
#     scatter_kws={'alpha': 0.6, 'edgecolor': 'white'}
# )

# Second plot with regression line added
plt.figure(figsize=(8, 8))
sns.regplot(
    data=demographics_df,
    x='Followup FVC Volume L',
    y='FEV1 Volume L',
    scatter_kws={'alpha': 0.6, 'edgecolor': 'white'},
    line_kws={'color': 'red', 'linewidth': 2}
)

plt.title('Followup FVC Volume vs FEV1 Volume')
plt.xlabel('Followup FVC Volume [L]')
plt.ylabel('FEV1 Volume [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.show()
# Out:
# Correlation between Followup FVC Volume and FEV1 Volume: 0.85

# %%
# Unified style
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 15,
    "axes.titlesize": 15,
    "axes.labelsize": 15,
    "legend.fontsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "axes.titlepad": 20,  # Add padding to titles

})


fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# (a) Baseline vs Follow-up FVC
axes[0].hist(demographics_df['Baseline FVC Volume L'], bins=50, alpha=0.6, label='Baseline FVC Volume L', edgecolor='white', color='#4C72B0')
axes[0].hist(demographics_df['Followup FVC Volume L'], bins=50, alpha=0.6, label='Followup FVC Volume L', edgecolor='white', color='#DD8452')

baseline_mean = demographics_df['Baseline FVC Volume L'].mean()
followup_mean = demographics_df['Followup FVC Volume L'].mean()

axes[0].axvline(baseline_mean, color='blue', linestyle='dashed', linewidth=1,
                label=f'Baseline Mean: {baseline_mean:.2f} L')
axes[0].axvline(followup_mean, color='red', linestyle='dashed', linewidth=1,
                label=f'Followup Mean: {followup_mean:.2f} L')

axes[0].set_xlabel('FVC Volume (L)')
axes[0].set_ylabel('Frequency')
axes[0].legend()

# Title under subplot
axes[0].text(0.5, -0.22, '(a) Distribution of Baseline and Follow-up FVC',
             transform=axes[0].transAxes, ha='center', va='top')
# no grid for x-axis, only y-axis

axes[0].grid(axis='y', alpha=0.4, linestyle='--')
axes[0].grid(axis='x', alpha=0.0, linestyle='--')


# (b) Delta FVC
axes[1].hist(demographics_df['Delta FVC'], bins=60, alpha=0.6, label='Delta FVC', edgecolor='white')
delta_mean = demographics_df['Delta FVC'].mean()

axes[1].axvline(delta_mean, color='red', linestyle='dashed', linewidth=1,
                label=f'Mean: {delta_mean:.2f} L')

axes[1].set_xlabel('Delta FVC (L)')
#axes[1].set_ylabel('Frequency')
axes[1].legend(fontsize=10)

# Title under subplot
axes[1].text(0.5, -0.22, '(b) Distribution of Delta FVC',
             transform=axes[1].transAxes, ha='center', va='top')
axes[1].grid(axis='y', alpha=0.4, linestyle='--')
axes[1].grid(axis='x', alpha=0.0, linestyle='--')


plt.tight_layout()
plt.show()

# %%
# mean std median of delta FVC
delta_mean = demographics_df['Delta FVC'].mean()
delta_std = demographics_df['Delta FVC'].std()
delta_median = demographics_df['Delta FVC'].median()
print(f"Delta FVC - Mean: {delta_mean:.2f} L, Std: {delta_std:.2f} L, Median: {delta_median:.2f} L")

# median of all numeric columns
print("\nMedian of Numeric Columns:")
print(demographics_df.median(numeric_only=True))
# Out:
# Delta FVC - Mean: -0.07 L, Std: 0.37 L, Median: -0.08 L
#
# Median of Numeric Columns:
# PatientID                1.000461e+06
# Age                      6.595545e+01
# FEV1 Volume L            2.000000e+00
# Baseline FVC Volume L    2.470000e+00
# Followup FVC Volume L    2.410000e+00
# Delta FVC               -8.000000e-02
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Clean, publication-style theme
#sns.set_theme(style="whitegrid")

plt.figure(figsize=(8, 5))


# Histogram of Delta FVC
sns.histplot(
    data=demographics_df,
    x='Delta FVC',
    bins=50,
    #color="#1C4FA1",           # colorblind-friendly blue
    edgecolor='white',
    alpha=0.5
)

# Mean line
mean_delta = demographics_df['Delta FVC'].mean()
plt.axvline(
    mean_delta,
    color='red',
    linestyle='--',
    linewidth=1.2,
    label=f'Mean: {mean_delta:.2f}'
)

# Labels and title
plt.title('Distribution of $\Delta$FVC', fontsize=12)
plt.xlabel('Change in FVC ($\Delta$FVC) [L]', fontsize=11)
plt.ylabel('Number of Patients', fontsize=11)

# Ticks
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# Legend
plt.legend(fontsize=9, frameon=True)

# Subtle grid
plt.grid(axis='y', alpha=0.35, linestyle='--')

# Layout for clean export
plt.tight_layout()

# Save figure (optional)
# plt.savefig('delta_fvc_distribution.pdf', dpi=300, bbox_inches='tight')

plt.show()

# %%
plt.rcParams.update({
    "font.family": "serif",
    "font.size": 15,
    "axes.titlesize": 12,
    "axes.labelsize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "axes.titlepad": 20,  # Add padding to titles

})
plt.figure(figsize=(8, 5))

# Baseline and follow-up histograms (no bar edges)
sns.histplot(
    data=demographics_df,
    x='Baseline FVC Volume L',
    bins=50,
    #color="#3470D1",
    alpha=0.6,
    linewidth=0.2,
    edgecolor='white',
    label='Baseline FVC'
)

sns.histplot(
    data=demographics_df,
    x='Followup FVC Volume L',
    bins=50,
    #color="#EE8C53",
    alpha=0.6,
    linewidth=0.2,
    edgecolor='white',
    label='Follow-up FVC'
)

# Compute means
baseline_mean = demographics_df['Baseline FVC Volume L'].mean()
followup_mean = demographics_df['Followup FVC Volume L'].mean()

# Mean lines
plt.axvline(
    baseline_mean,
    color="#3470D1",
    linestyle='--',
    linewidth=2,
    label=f'Baseline mean: {baseline_mean:.2f} L'
)

plt.axvline(
    followup_mean,
    color="#F7551A",
    linestyle='--',
    linewidth=2,
    label=f'Follow-up mean: {followup_mean:.2f} L'
)

plt.rcParams.update({
    "font.family": "serif",
    "font.size": 15,
    "axes.titlesize": 12,
    "axes.labelsize": 11,
    "legend.fontsize": 9,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10,
    "axes.titlepad": 20,  # Add padding to titles

})

plt.title('Distribution of Baseline and Follow-up FVC Volumes')
plt.xlabel('FVC Volume [L]')
plt.ylabel('Number of Patients')
plt.grid(axis='y', alpha=0.35, linestyle='--')
plt.tight_layout()
plt.show()

# %%
# summary correlation between all numerical features

numerical_cols = ['FEV1 Volume L', 'Baseline FVC Volume L', 'Followup FVC Volume L', 'Delta FVC', 'Age']
correlation_matrix = demographics_df[numerical_cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True, linewidths=0.5, linecolor='white')
plt.title('Correlation Matrix of Demographic and Clinical Features')
plt.tight_layout()
plt.show()

# %%
# Correlation including categorical features (via one-hot encoding)

categorical_cols = ['Primary Diagnosis', 'Sex', 'Smoking History']

# Keep numeric + categorical, then encode categoricals
corr_df = demographics_df[numerical_cols + categorical_cols].copy()
corr_df_encoded = pd.get_dummies(corr_df, columns=categorical_cols, drop_first=False)

# Correlation matrix on encoded data
correlation_matrix_all = corr_df_encoded.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(
    correlation_matrix_all,
    cmap='coolwarm',
    center=0,
    cbar=True,
    linewidths=0.3,
    linecolor='white'
)
plt.title('Correlation Matrix (Numerical + Encoded Categorical Features)')
plt.tight_layout()
plt.show()

# Optional: compact view -> correlations with Delta FVC only
delta_corr = correlation_matrix_all['Delta FVC'].sort_values(ascending=False)
print(delta_corr)
# Out:
# Delta FVC                        1.000000
# Followup FVC Volume L            0.295229
# Primary Diagnosis_Other          0.121931
# Smoking History_Active Smoker    0.112071
# Primary Diagnosis_CTD-ILD        0.070760
# Smoking History_Unknown          0.038440
# Sex_Female                       0.017397
# Smoking History_Never Smoker    -0.013971
# Sex_Male                        -0.017397
# Primary Diagnosis_CHP           -0.039907
# Primary Diagnosis_UILD          -0.041427
# Smoking History_Ex Smoker       -0.044163
# Primary Diagnosis_IPF           -0.081851
# FEV1 Volume L                   -0.129401
# Baseline FVC Volume L           -0.138073
# Age                             -0.197700
# Name: Delta FVC, dtype: float64

# %% [markdown]
# ## Model Performance

# %% [markdown]
# ================================================================================
# MLP CROSS-VALIDATION COMPLETE
# ================================================================================
# Fold metrics saved to: cv_tabular_one_hot_2026-03-10_13-20-06/cv_fold_metrics_tabular_one_hot_all_seeds_fold_15_bs4_pt556_2026-03-10_13-20-06.csv
# CV summary saved to: cv_tabular_one_hot_2026-03-10_13-20-06/cv_summary_tabular_one_hot_all_seeds_fold_15_bs4_pt556_2026-03-10_13-20-06.csv
# All artifacts saved under: cv_tabular_one_hot_2026-03-10_13-20-06
#
# ================================================================================
# RANDOM FOREST TRAINING COMPLETE
# ================================================================================
# Grid search results saved to: cv_rf_one_hot_2026-03-10_13-23-51/grid_search_results_rf_2026-03-10_13-23-51.csv
# Best params saved to: cv_rf_one_hot_2026-03-10_13-23-51/best_rf_params_2026-03-10_13-23-51.json
# Fold metrics saved to: cv_rf_one_hot_2026-03-10_13-23-51/cv_fold_metrics_rf_one_hot_fold_15_2026-03-10_13-23-51.csv
# CV summary saved to: cv_rf_one_hot_2026-03-10_13-23-51/cv_summary_rf_one_hot_fold_15_2026-03-10_13-23-51.csv
# CV boxplot saved to: cv_rf_one_hot_2026-03-10_13-23-51/cv_metrics_boxplot_rf_one_hot_fold_15_2026-03-10_13-23-51.png
# Mean feature importance CSV saved to: cv_rf_one_hot_2026-03-10_13-23-51/feature_importance_mean_rf_one_hot_2026-03-10_13-23-51.csv
# Mean feature importance plot saved to: cv_rf_one_hot_2026-03-10_13-23-51/feature_importance_mean_rf_one_hot_2026-03-10_13-23-51.png
# All artifacts saved under: cv_rf_one_hot_2026-03-10_13-23-51
#
#
# ================================================================================
# MULTI SEED 42 CROSS-VALIDATION COMPLETE
# ================================================================================
# Fold metrics saved to: cv_multi_one_hot_5_cv/cv_fold_metrics_seed42_multi_all_fold_5_2026-03-02_16-20-48.csv
# CV summary saved to: cv_multi_one_hot_5_cv/cv_summary_seed42_multi_all_fold_5_2026-03-02_16-20-48.csv
# All artifacts saved under: cv_multi_one_hot_5_cv

# %% [markdown]
# # Model Performance
# # Tabular only Performance

# %%
# Box plot of Tabular model performance (R2 score) 
multimodal_metric_s42 = pd.read_csv('cv_multi_one_hot_5_cv/cv_fold_metrics_seed42_multi_all_fold_5_2026-03-02_16-20-48.csv')
metric_rf = pd.read_csv('cv_rf_one_hot_2026-03-10_13-23-51/cv_fold_metrics_rf_one_hot_fold_15_2026-03-10_13-23-51.csv')
metric_mlp = pd.read_csv('cv_tabular_one_hot_2026-03-10_13-20-06/cv_fold_metrics_tabular_one_hot_all_seeds_fold_15_bs4_pt556_2026-03-10_13-20-06.csv')


timestamp = '2026-03-20_21-02-47'
folds = [1, 2, 3, 4, 5]
# read all folds for multimodal model with seed 42 and scaled data
all_eval_df = pd.DataFrame()
all_validation_df = pd.DataFrame()
for fold in folds:
    path_eval = f'/home/chanutem/OSIC_Analysis/cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/evaluation_metrics_seed42_fold{fold}_multi_all_{timestamp}.csv'
    #path_loss = f'/home/chanutem/OSIC_Analysis/cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/loss_history_seed42_fold{fold}_multi_all_{timestamp}.csv'
    path_validation = f'/home/chanutem/OSIC_Analysis/cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/validation_metrics_seed42_fold{fold}_multi_all_{timestamp}.csv'
    eval_df = pd.read_csv(path_eval)
    #loss_df = pd.read_csv(path_loss)
    validation_df = pd.read_csv(path_validation)
    # print(f"Fold {fold} - Evaluation Metrics:")
    # print(eval_df.head())
    # #print(f"Fold {fold} - Loss History:")
    # #print(loss_df.head())
    # print(f"Fold {fold} - Validation Metrics:")
    #print(validation_df.head())
    all_eval_df = pd.concat([eval_df, all_eval_df], ignore_index=True) if 'all_eval_df' in locals() else eval_df
    all_validation_df = pd.concat([validation_df, all_validation_df], ignore_index=True) if 'all_validation_df' in locals() else validation_df

# %%
all_eval_df
# Out:
#              Timestamp  Seed  Fold  Global_Fold  Batch_Size  Learning_Rate  \
# 0  2026-03-20_21-02-47    42     5            5           4          0.005
# 1  2026-03-20_21-02-47    42     4            4           4          0.005
# 2  2026-03-20_21-02-47    42     3            3           4          0.005
# 3  2026-03-20_21-02-47    42     2            2           4          0.005
# 4  2026-03-20_21-02-47    42     1            1           4          0.005
#
#    Weight_Decay  Early_Stopping_Patience  Total_Patients  Train_Samples  \
# 0  1.000000e-07                       22             556            378
# 1  1.000000e-07                       22             556            378
# 2  1.000000e-07                       22             556            378
# 3  1.000000e-07                       22             556            377
# 4  1.000000e-07                       22             556            377
#
#    Val_Samples  Test_Samples       MSE      RMSE       MAE  R2_Score  \
# ...

# %%
metric_mlp_s42 = metric_mlp[metric_mlp['Seed'] == 42]
metric_rf_s42 = metric_rf[metric_rf['Seed'] == 42]

# %%
# box plot of R2 score for multimodal validation vs evaluation
plt.figure(figsize=(8, 6))
# sns.boxplot(
#     data=all_eval_df,
#     x='Seed',
#     y='R2_Score',
#     palette='Set2',
#     width=0.5
# )
sns.stripplot(
    data=all_eval_df,
    x='Fold',
    y='R2_Score',
    color='black',
    size=7,
    jitter=True,
    alpha=0.7,
    label='Evaluation R2 Score'
)

sns.stripplot(
    data=all_validation_df,
    x='Fold',
    y='R2_Score',
    color='green',
    size=7,
    jitter=True,
    alpha=0.7,
    #label='Validation R2 Score'
)
# add mean line for evaluation
eval_mean = all_eval_df['R2_Score'].mean()
plt.axhline(
    eval_mean,
    color='black',
    linestyle='--',
    linewidth=1.2,
    label=f'Evaluation Mean: {eval_mean:.3f}'
)
validation_mean = all_validation_df['R2_Score'].mean()
plt.axhline(
    validation_mean,
    color='green',
    linestyle='--',
    linewidth=1.2,
    label=f'Validation Mean: {validation_mean:.3f}'
)
plt.title('R2 Score Distribution Across Folds (Multimodal Model)', fontsize=12)
plt.xlabel('Fold', fontsize=11)
plt.ylabel('R2 Score', fontsize=11)
plt.legend( fontsize=9, frameon=True)
plt.grid(alpha=0.1)
plt.tight_layout()
plt.show()

# %%
summary_run = pd.read_csv('/home/chanutem/OSIC_Analysis/slurm_summary_success_no_xai_multimodal.csv')

# %%
summary_run
# Out:
#     MAE_last  MAE_mean   MAE_std  MSE_last  MSE_mean   MSE_std   R2_last  \
# 0   0.569379       NaN       NaN  0.476043       NaN       NaN       NaN
# 1   0.561868       NaN       NaN  0.491916       NaN       NaN       NaN
# 2   0.635165       NaN       NaN  0.558010       NaN       NaN       NaN
# 3   0.443884       NaN       NaN  0.313058       NaN       NaN       NaN
# 4   0.597879       NaN       NaN  0.530124       NaN       NaN       NaN
# 5   0.552656       NaN       NaN  0.474625       NaN       NaN       NaN
# 6   0.518250       NaN       NaN  0.434603       NaN       NaN       NaN
# 7   0.524428       NaN       NaN  0.473748       NaN       NaN       NaN
# 8   0.560187       NaN       NaN  0.464918       NaN       NaN       NaN
# 9   0.556027       NaN       NaN  0.474958       NaN       NaN       NaN
# 10  0.545408       NaN       NaN  0.490796       NaN       NaN       NaN
# 11  0.504029       NaN       NaN  0.381832       NaN       NaN       NaN
# ...

# %%
metric_rf.head()
# Out:
#    Seed  Fold  Global_Fold  Train_Samples  Val_Samples  Test_Samples  \
# 0    42     1            1            377           95            84
# 1    42     2            2            377           95            84
# 2    42     3            3            378           94            84
# 3    42     4            4            378           94            84
# 4    42     5            5            378           94            84
#
#         MSE      RMSE       MAE  R2_Score  Test_MSE  Test_RMSE  Test_MAE  \
# 0  0.116544  0.341385  0.239310  0.862599  0.091148   0.301907  0.204681
# 1  0.165052  0.406266  0.280965  0.792648  0.090515   0.300857  0.209893
# 2  0.165628  0.406974  0.278400  0.777277  0.095905   0.309686  0.222991
# 3  0.199158  0.446271  0.272464  0.723907  0.090522   0.300869  0.211250
# 4  0.131674  0.362870  0.270655  0.821392  0.081448   0.285390  0.201174
#
#    Test_R2_Score
# 0       0.870828
# 1       0.871725
# 2       0.864086
# 3       0.871715
# 4       0.884575

# %%
metric_mlp.head()
# Out:
#    Seed  Fold  Global_Fold  Train_Samples  Val_Samples  Test_Samples  \
# 0    42     1            1            377           95            84
# 1    42     2            2            377           95            84
# 2    42     3            3            378           94            84
# 3    42     4            4            378           94            84
# 4    42     5            5            378           94            84
#
#         MSE      RMSE       MAE  R2_Score  Test_MSE  Test_RMSE  Test_MAE  \
# 0  0.097914  0.312912  0.221048  0.884564  0.091155   0.301920  0.214488
# 1  0.155357  0.394153  0.281788  0.804829  0.085685   0.292720  0.200277
# 2  0.159948  0.399935  0.284155  0.784914  0.092098   0.303476  0.218982
# 3  0.167039  0.408704  0.269669  0.768433  0.090699   0.301163  0.210211
# 4  0.124021  0.352166  0.264148  0.831773  0.087433   0.295690  0.205517
#
#    Test_R2_Score  Best_Val_Loss  Total_Epochs  \
# 0       0.870817       0.097674            54
# ...

# %%
multimodal_metric_s42.head()
# Out:
#    Fold  Train_Samples  Val_Samples       MSE      RMSE       MAE  R2_Score  \
# 0     1            377           95  0.139157  0.373038  0.278861  0.835939
# 1     2            377           95  0.179023  0.423111  0.316453  0.775097
# 2     3            378           94  0.124161  0.352365  0.262129  0.833038
# 3     4            378           94  0.167599  0.409388  0.308127  0.767657
# 4     5            378           94  0.141538  0.376215  0.289037  0.808013
#
#    Best_Val_Loss  Total_Epochs  \
# 0       0.138779            26
# 1       0.180959            36
# 2       0.121787            48
# 3       0.165825            68
# 4       0.141412            47
#
#                                      Best_Model_Path
# 0  cv_multi_one_hot_5_cv/best_model_seed42_fold1_...
# 1  cv_multi_one_hot_5_cv/best_model_seed42_fold2_...
# 2  cv_multi_one_hot_5_cv/best_model_seed42_fold3_...
# 3  cv_multi_one_hot_5_cv/best_model_seed42_fold4_...
# ...

# %%
# Build model-labeled metrics table for plotting
comparison_df = pd.concat([
    multimodal_metric_s42[['MSE', 'RMSE', 'MAE', 'R2_Score']].assign(Model='Multimodal'),
    metric_rf[['MSE', 'RMSE', 'MAE', 'R2_Score']].assign(Model='Random Forest'),
    metric_mlp[['MSE', 'RMSE', 'MAE', 'R2_Score']].assign(Model='MLP (Tabular)')
])

# Long format for seaborn
plot_df = comparison_df.melt(
    id_vars='Model',
    value_vars=['MSE', 'RMSE', 'MAE', 'R2_Score'],
    var_name='Metric',
    value_name='Value'
)

# Plot model comparison
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
metric_order = ['MSE', 'RMSE', 'MAE', 'R2_Score']
model_order = ['Multimodal', 'Random Forest', 'MLP (Tabular)']

for ax, metric in zip(axes.flatten(), metric_order):
    sns.boxplot(
        data=plot_df[plot_df['Metric'] == metric],
        x='Model',
        y='Value',
        order=model_order,
        ax=ax,
        showmeans=True,
        meanprops={
            'marker': 'o',
            'markerfacecolor': 'white',
            'markeredgecolor': 'black',
            'markersize': 5
        }
    )
    ax.set_title(metric)
    ax.set_xlabel('')
    ax.tick_params(axis='x', rotation=15)
    ax.grid(axis='y', alpha=0.3, linestyle='--')

fig.suptitle('Model Performance Comparison Across Folds', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Build model-labeled metrics table for plotting
comparison_df_test = pd.concat([
    metric_rf[['Test_MSE', 'Test_RMSE', 'Test_MAE', 'Test_R2_Score']].assign(Model='Random Forest'),
    metric_mlp[['Test_MSE', 'Test_RMSE', 'Test_MAE', 'Test_R2_Score']].assign(Model='MLP (Tabular)')
])


# Plot model comparison
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
metric_order = ['Test_MSE', 'Test_RMSE', 'Test_MAE', 'Test_R2_Score']
model_order = [ 'Random Forest', 'MLP (Tabular)']

for ax, metric in zip(axes.flatten(), metric_order):
    sns.boxplot(
        data=comparison_df_test.melt(id_vars='Model', var_name='Metric', value_name='Value')[lambda df: df['Metric'] == metric],
        x='Model',
        y='Value',
        order=model_order,
        ax=ax,
        showmeans=True,
        meanprops={
            'marker': 'o',
            'markerfacecolor': 'white',
            'markeredgecolor': 'black',
            'markersize': 5
        }
    )
    ax.set_title(metric)
    ax.set_xlabel('')
    ax.tick_params(axis='x', rotation=15)
    ax.grid(axis='y', alpha=0.3, linestyle='--')

fig.suptitle('Model Performance Comparison Across Folds', y=1.02)
plt.tight_layout()
plt.show()

# %%
# print mean and std of each metric for each model
for model in model_order:
    print(f"Model: {model}")
    for metric in metric_order:
        
        mean_val = comparison_df_test[comparison_df_test['Model'] == model][metric].mean()
        std_val = comparison_df_test[comparison_df_test['Model'] == model][metric].std()
        print(f"  {metric}: Mean = {mean_val:.3f}, Std = {std_val:.3f}")
# Out:
# Model: Random Forest
#   Test_MSE: Mean = 0.089, Std = 0.003
#   Test_RMSE: Mean = 0.299, Std = 0.006
#   Test_MAE: Mean = 0.209, Std = 0.005
#   Test_R2_Score: Mean = 0.873, Std = 0.005
# Model: MLP (Tabular)
#   Test_MSE: Mean = 0.091, Std = 0.005
#   Test_RMSE: Mean = 0.302, Std = 0.009
#   Test_MAE: Mean = 0.213, Std = 0.009
#   Test_R2_Score: Mean = 0.871, Std = 0.008

# %%
df_example = pd.read_csv('cv_rf_one_hot_2026-03-10_13-23-51/test_metrics_seed7_fold1_rf_one_hot_2026-03-10_13-23-51.csv')
df_example
# Out:
#              Timestamp  Seed  Fold  Global_Fold  Total_Patients  \
# 0  2026-03-10_13-23-51     7     1           11             556
#
#    Train_Samples  Val_Samples  Test_Samples       MSE      RMSE       MAE  \
# 0            377           95            84  0.089965  0.299942  0.212906
#
#    R2_Score  MSE_CI_Lower  MSE_CI_Upper  RMSE_CI_Lower  RMSE_CI_Upper  \
# 0  0.872504      0.049923       0.14252       0.223434       0.377518
#
#    MAE_CI_Lower  MAE_CI_Upper  R2_CI_Lower  R2_CI_Upper  Bootstrap_Resamples  \
# 0      0.172127       0.26175      0.77423     0.933041                 1000
#
#    Bootstrap_CI_Alpha                                        Best_Params
# 0                0.95  {"max_depth": null, "max_features": null, "min...

# %%
seeds = [42]#,24,7]
# folds 1-5
folds = [1,2,3,4,5]
directory = 'cv_rf_one_hot_2026-03-10_13-23-51/'

# concatenate all test metrics into one dataframe
test_metrics_df_rf = pd.DataFrame()
for seed in seeds:
    for fold in folds:
        df = pd.read_csv(f"{directory}test_metrics_seed{seed}_fold{fold}_rf_one_hot_2026-03-10_13-23-51.csv")
        test_metrics_df_rf = pd.concat([test_metrics_df_rf, df], ignore_index=True)
        print(f"Seed: {seed}, Fold: {fold}")
# Out:
# Seed: 42, Fold: 1
# Seed: 42, Fold: 2
# Seed: 42, Fold: 3
# Seed: 42, Fold: 4
# Seed: 42, Fold: 5

# %%
#same for mlp cv_tabular_one_hot_2026-03-10_13-20-06/test_metrics_seed7_fold1_tabular_one_hot_bs4_pt556_2026-03-10_13-20-06.csv
# /home/chanutem/OSIC_Analysis/cv_tabular_one_hot_2026-04-08_12-07-48/evaluation_metrics_seed42_fold1_tabular_one_hot_bs4_pt556_2026-04-08_12-07-48.csv
#cv_tabular_one_hot_2026-04-08_12-07-48
#cv_tabular_one_hot_2026-03-31_15-22-26
#directory_mlp = 'cv_tabular_one_hot_2026-04-08_12-07-48/'
directory_mlp = 'cv_tabular_one_hot_2026-03-31_15-22-26/'
timestamp_mlp = '2026-03-31_15-22-26'
#directory_mlp = 'cv_tabular_one_hot_2026-03-10_13-20-06/'
test_metrics_df_mlp = pd.DataFrame()#'cv_tabular_one_hot_2026-04-08_12-07-48/'#
for seed in seeds:
    for fold in folds:
        df = pd.read_csv(f"{directory_mlp}test_metrics_seed{seed}_fold{fold}_tabular_one_hot_bs4_pt556_{timestamp_mlp}.csv")
        test_metrics_df_mlp = pd.concat([test_metrics_df_mlp, df], ignore_index=True)
        print(f"Seed: {seed}, Fold: {fold}")
# Out:
# Seed: 42, Fold: 1
# Seed: 42, Fold: 2
# Seed: 42, Fold: 3
# Seed: 42, Fold: 4
# Seed: 42, Fold: 5

# %%
cols = [
	'Best_Val_Loss', 'Total_Epochs', 'Input_Dim', 'Hidden_Dim', 'Batch_Size',
	'Learning_Rate', 'Weight_Decay', 'Early_Stopping_Patience',
	'Total_Patients', 'Train_Samples', 'Val_Samples', 'Test_Samples'
]

available_cols = [c for c in cols if c in test_metrics_df_mlp.columns]
missing_cols = [c for c in cols if c not in test_metrics_df_mlp.columns]

print("Missing columns:", missing_cols)
test_metrics_df_mlp[available_cols]
# Out:
# Missing columns: []
#    Best_Val_Loss  Total_Epochs  Input_Dim  Hidden_Dim  Batch_Size  \
# 0       0.095806            57         14         256           4
# 1       0.159170            44         14         256           4
# 2       0.154427            34         14         256           4
# 3       0.167193            24         14         256           4
# 4       0.118837            30         14         256           4
#
#    Learning_Rate  Weight_Decay  Early_Stopping_Patience  Total_Patients  \
# 0         0.0005       0.00001                       20             556
# 1         0.0005       0.00001                       20             556
# 2         0.0005       0.00001                       20             556
# 3         0.0005       0.00001                       20             556
# 4         0.0005       0.00001                       20             556
#
#    Train_Samples  Val_Samples  Test_Samples
# 0            377           95            84
# ...

# %%
test_metrics_df_mlp.columns
# Out:
# Index(['Timestamp', 'Seed', 'Fold', 'Global_Fold', 'Batch_Size',
#        'Learning_Rate', 'Weight_Decay', 'Early_Stopping_Patience',
#        'Total_Patients', 'Train_Samples', 'Val_Samples', 'Test_Samples', 'MSE',
#        'RMSE', 'MAE', 'R2_Score', 'MSE_CI_Lower', 'MSE_CI_Upper',
#        'RMSE_CI_Lower', 'RMSE_CI_Upper', 'MAE_CI_Lower', 'MAE_CI_Upper',
#        'R2_CI_Lower', 'R2_CI_Upper', 'Bootstrap_Resamples',
#        'Bootstrap_CI_Alpha', 'Best_Val_Loss', 'Total_Epochs', 'Input_Dim',
#        'Hidden_Dim', 'Best_Model_Path'],
#       dtype='object')

# %%
# Plot performance distribution for test metrics
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
metric_order = ['MSE', 'RMSE', 'MAE', 'R2_Score']
model_order = ['Random Forest', 'MLP (Tabular)']
for ax, metric in zip(axes.flatten(), metric_order):
    sns.boxplot(
        data=pd.concat([
            test_metrics_df_rf[[metric]].assign(Model='Random Forest'),
            test_metrics_df_mlp[[metric]].assign(Model='MLP (Tabular)')
        ], ignore_index=True).rename(columns={metric: 'Value'}),
        x='Model',
        y='Value',
        order=model_order,
        ax=ax,
        showmeans=True,
        meanprops={
            'marker': 'o',
            'markerfacecolor': 'white',
            'markeredgecolor': 'grey',
            'markersize': 5
        }
    )
    if metric == 'R2_Score':
        title = 'Test R² Score'
    else:        title = 'Test ' + metric
    ax.set_title(title)
    ax.set_xlabel('')
    ax.tick_params(axis='x', rotation=15)
    ax.grid(axis='y', alpha=0.3, linestyle='--')
fig.suptitle('Test Performance Comparison Across Folds', y=1.02)
plt.tight_layout()
plt.show()

# %%
test_metrics_df_mlp
# Out:
#              Timestamp  Seed  Fold  Global_Fold  Batch_Size  Learning_Rate  \
# 0  2026-03-31_15-22-26    42     1            1           4         0.0005
# 1  2026-03-31_15-22-26    42     2            2           4         0.0005
# 2  2026-03-31_15-22-26    42     3            3           4         0.0005
# 3  2026-03-31_15-22-26    42     4            4           4         0.0005
# 4  2026-03-31_15-22-26    42     5            5           4         0.0005
#
#    Weight_Decay  Early_Stopping_Patience  Total_Patients  Train_Samples  \
# 0       0.00001                       20             556            377
# 1       0.00001                       20             556            377
# 2       0.00001                       20             556            378
# 3       0.00001                       20             556            378
# 4       0.00001                       20             556            378
#
#    Val_Samples  Test_Samples       MSE      RMSE       MAE  R2_Score  \
# ...

# %%
# print summary statistics for test metrics
for model in model_order:
    print(f"Model: {model}")
    for metric in metric_order:
        if model == 'Random Forest':
            data = test_metrics_df_rf[metric]
        else:
            data = test_metrics_df_mlp[metric]
        mean_val = data.mean()
        std_val = data.std()
        print(f"  {metric}: Mean = {mean_val:.3f}, Std = {std_val:.3f}")
# Out:
# Model: Random Forest
#   MSE: Mean = 0.090, Std = 0.005
#   RMSE: Mean = 0.300, Std = 0.009
#   MAE: Mean = 0.210, Std = 0.008
#   R2_Score: Mean = 0.873, Std = 0.007
# Model: MLP (Tabular)
#   MSE: Mean = 0.092, Std = 0.003
#   RMSE: Mean = 0.303, Std = 0.004
#   MAE: Mean = 0.219, Std = 0.008
#   R2_Score: Mean = 0.870, Std = 0.004

# %%
## Plot with bootstrapped confidence intervals for test metrics

bootstrap_columns = ['RMSE_CI_Lower', 'RMSE_CI_Upper', 'MAE_CI_Lower', 'MAE_CI_Upper', 'R2_CI_Lower', 'R2_CI_Upper']
# Assuming these columns exist in the test metrics dataframes
fig, axes = plt.subplots(2, 2, figsize=(12, 12))
metric_order = ['RMSE', 'MAE', 'R2_Score']
model_order = ['Random Forest', 'MLP (Tabular)']
for ax, metric in zip(axes.flatten(), metric_order):
    if metric in ['RMSE', 'MAE', 'R2_Score']:
        if metric == 'R2_Score':
            ci_lower_col = metric.replace('R2_Score', 'R2') + '_CI_Lower'
            ci_upper_col = metric.replace('R2_Score', 'R2') + '_CI_Upper'
        else:
            ci_lower_col = metric + '_CI_Lower'
            ci_upper_col = metric + '_CI_Upper'
        sns.boxplot(
            data=pd.concat([
                test_metrics_df_rf[[metric, ci_lower_col, ci_upper_col]].assign(Model='Random Forest'),
                test_metrics_df_mlp[[metric, ci_lower_col, ci_upper_col]].assign(Model='MLP (Tabular)')
            ], ignore_index=True).rename(columns={metric: 'Value'}),
            x='Model',
            y='Value',
            order=model_order,
            ax=ax,
            showmeans=True,
            meanprops={
                'marker': 'o',
                'markerfacecolor': 'white',
                'markeredgecolor': 'grey',
                'markersize': 5
            }
        )
        # Add error bars for confidence intervals
        for i, model in enumerate(model_order):
            subset = pd.concat([
                test_metrics_df_rf[[metric, ci_lower_col, ci_upper_col]].assign(Model='Random Forest'),
                test_metrics_df_mlp[[metric, ci_lower_col, ci_upper_col]].assign(Model='MLP (Tabular)')
            ], ignore_index=True).rename(columns={metric: 'Value'})
            model_data = subset[subset['Model'] == model]
            mean_value = model_data['Value'].mean()
            ci_lower = model_data[ci_lower_col].mean()
            ci_upper = model_data[ci_upper_col].mean()
            ax.errorbar(i, mean_value, yerr=[[mean_value - ci_lower], [ci_upper - mean_value]], fmt='none', c='black', capsize=5)
    else:
        sns.boxplot(
            data=pd.concat([
                test_metrics_df_rf[[metric]].assign(Model='Random Forest'),
                test_metrics_df_mlp[[metric]].assign(Model='MLP (Tabular)')
            ], ignore_index=True).rename(columns={metric: 'Value'}),
            x='Model',
            y='Value',
            order=model_order,
            ax=ax,
            showmeans=True,
            meanprops={
                'marker': 'o',
                'markerfacecolor': 'white',
                'markeredgecolor': 'grey',
                'markersize': 5
            }
        )
    ax.set_title('Test ' + metric)
    ax.set_xlabel('')
    ax.tick_params(axis='x', rotation=15)
    ax.grid(axis='y', alpha=0.3, linestyle='--')
fig.suptitle('Test Performance Comparison with Bootstrapped CIs', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Tabular prediction plot

# %%
mlp_predictions = pd.read_csv('cv_tabular_one_hot_2026-03-31_15-22-26/Evaluation_2026-04-14_15-42-18/per_patient_all_folds_predictions_2026-04-14_15-42-18.csv')

# %%
mlp_predictions.columns
# Out:
# Index(['PatientID', 'Age', 'Sex', 'Primary Diagnosis', 'Smoking History',
#        'Baseline FVC Volume L', 'FEV1 Volume L', 'Age_Group',
#        'True_FVC_Volume_L', 'Pred_FVC_Fold1', 'AbsError_Fold1',
#        'Residual_Fold1', 'Pred_FVC_Fold2', 'AbsError_Fold2', 'Residual_Fold2',
#        'Pred_FVC_Fold3', 'AbsError_Fold3', 'Residual_Fold3', 'Pred_FVC_Fold4',
#        'AbsError_Fold4', 'Residual_Fold4', 'Pred_FVC_Fold5', 'AbsError_Fold5',
#        'Residual_Fold5', 'Ensemble_Pred', 'Ensemble_Std', 'Ensemble_Range',
#        'Ensemble_AbsError', 'Ensemble_Residual', 'Ensemble_PctError',
#        'Fold_Pred_Std', 'Fold_Pred_Range'],
#       dtype='object')

# %%
#Index(['PatientID', 'Age', 'Sex', 'Primary Diagnosis', 'Smoking History',
    #    'Baseline FVC Volume L', 'FEV1 Volume L', 'Age_Group',
    #    'True_FVC_Volume_L', 'Pred_FVC_Fold1', 'AbsError_Fold1',
    #    'Residual_Fold1', 'Pred_FVC_Fold2', 'AbsError_Fold2', 'Residual_Fold2',
    #    'Pred_FVC_Fold3', 'AbsError_Fold3', 'Residual_Fold3', 'Pred_FVC_Fold4',
    #    'AbsError_Fold4', 'Residual_Fold4', 'Pred_FVC_Fold5', 'AbsError_Fold5',
    #    'Residual_Fold5', 'Ensemble_Pred', 'Ensemble_Std', 'Ensemble_Range',
    #    'Ensemble_AbsError', 'Ensemble_Residual', 'Ensemble_PctError',
    #    'Fold_Pred_Std', 'Fold_Pred_Range'],
    #   dtype='object')

pred_cols = [col for col in mlp_predictions.columns if col.startswith('Pred_FVC')]
mlp_predictions['Predicted_FVC_Mean'] = mlp_predictions[pred_cols].mean(axis=1)
mlp_predictions['Predicted_FVC_Std'] = mlp_predictions[pred_cols].std(axis=1)
mlp_predictions[['PatientID', 'True_FVC_Volume_L', 'Predicted_FVC_Mean', 'Predicted_FVC_Std']]
#plot predicted FVC mean vs true FVC with error bars for std
plt.figure(figsize=(8, 6))
plt.errorbar(
    mlp_predictions['True_FVC_Volume_L'],
    mlp_predictions['Predicted_FVC_Mean'],
    yerr=mlp_predictions['Predicted_FVC_Std'],
    fmt='o',
    ecolor='lightgray',
    elinewidth=2,
    capsize=0
)
plt.plot([mlp_predictions['True_FVC_Volume_L'].min(), mlp_predictions['True_FVC_Volume_L'].max()], [mlp_predictions['True_FVC_Volume_L'].min(), mlp_predictions['True_FVC_Volume_L'].max()], 'r--')  # line y=x for reference
#plt.title('Predicted FVC vs True FVC with Error Bars')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.legend(['Perfect Prediction', 'Mean Predicted FVC with Std Dev'])
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'mlp_predicted_vs_true_fvc_with_error_bars.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# plot pred statistics colored by diagnosis
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=mlp_predictions,
    x='True_FVC_Volume_L',
    y='Predicted_FVC_Mean',
    hue='Primary Diagnosis',
    palette='Set2',
    s=100,
    edgecolor='white'
)
plt.plot([mlp_predictions['True_FVC_Volume_L'].min(), mlp_predictions['True_FVC_Volume_L'].max()], [mlp_predictions['True_FVC_Volume_L'].min(), mlp_predictions['True_FVC_Volume_L'].max()], 'r--')  # line y=x for reference
plt.title('Predicted FVC vs True FVC Colored by Primary Diagnosis')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.legend(title='Primary Diagnosis')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'osmlp_predicted_vs_true_fvc_by_diagnosis.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
mlp_predictions = mlp_predictions.merge(demographics_df[['PatientID', 'Delta FVC']], on='PatientID', how='left')

# %%
# plot colored by delta FVC
# add cloumn delta FVC to mlp_predictions by merging with demographics_df

plt.errorbar(
    mlp_predictions['True_FVC_Volume_L'],
    mlp_predictions['Predicted_FVC_Mean'],
    yerr=mlp_predictions['Predicted_FVC_Std'],
    fmt='none',
    ecolor='lightgray',
    elinewidth=1,
    alpha=0.7,
    capsize=0,
    zorder=1
)

scatter = plt.scatter(
    mlp_predictions['True_FVC_Volume_L'],
    mlp_predictions['Predicted_FVC_Mean'],
    c=mlp_predictions['Delta FVC'],
    cmap='viridis',
    alpha=0.8,
    edgecolor='white',
    zorder=2
)

plt.plot([mlp_predictions['True_FVC_Volume_L'].min(), mlp_predictions['True_FVC_Volume_L'].max()], [mlp_predictions['True_FVC_Volume_L'].min(), mlp_predictions['True_FVC_Volume_L'].max()], 'r--')  # line y=x for reference
#plt.title('MLP Tabular Model: Predicted FVC vs True FVC Colored by Delta FVC')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.colorbar(scatter, label='Delta FVC [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'mlp_predicted_vs_true_fvc_by_delta_fvc.png'), dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Trend per-patient CSV saved to: cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/Explainability_Outputs_42_fold1_scaled/trend_classification_per_patient_seed42_2026-03-26_15-00-11.csv
# Trend confusion CSV saved to: cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/Explainability_Outputs_42_fold1_scaled/trend_classification_confusion_seed42_2026-03-26_15-00-11.csv
# Trend summary CSV saved to: cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/Explainability_Outputs_42_fold1_scaled/trend_classification_summary_seed42_2026-03-26_15-00-11.csv

# %%
confusion_matrix_df = pd.read_csv('cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/Explainability_Outputs_42_fold1_scaled/trend_classification_confusion_seed42_2026-03-26_15-00-11.csv')
confusion_matrix_df.head()
# Out:
#       True  Decline  Stable  Improve
# 0  Decline       26       5        2
# 1   Stable        9      13        7
# 2  Improve        7       5       10

# %%
# plot confusion matrix as heatmap
plt.figure(figsize=(6, 5))
sns.heatmap(
    confusion_matrix_df.set_index('True'),
    annot=True,
    fmt='d',
    cmap='Blues',
    cbar=False,
    linewidths=0.5,
    linecolor='white'
)
plt.title('Confusion Matrix for Trend Classification (Seed 42, Fold 1)')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.show()

# %%
trend = pd.read_csv('cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/Explainability_Outputs_42_fold1_scaled/trend_classification_per_patient_seed42_2026-03-26_15-00-11.csv')
# print patient where True_Trend not equal to Pred_Trend
mismatch_trend = trend[trend['True_Trend'] != trend['Pred_Trend']]
mismatch_trend
# Out:
#     PatientID  Baseline_FVC  True_Followup_FVC  Pred_Followup_FVC  \
# 1      894746          4.01              4.190           3.736414
# 2      469929          3.83              3.790           3.231538
# 3     1000842          1.55              1.730           1.564343
# 4      781116          2.29              2.260           2.471024
# 5      453782          3.16              3.120           2.903206
# 6      415344          2.75              2.690           2.633035
# 8      492401          2.76              2.820           2.978393
# 9     1001405          1.28              1.320           1.405185
# 10     256868          2.10              2.250           2.103833
# 13    1001096          1.87              1.860           2.075322
# 15    1001052          2.48              2.600           2.136079
# 19     322456          2.06              1.740           2.018330
# 22    1000590          2.98              2.700           2.911518
# ...

# %%
# plot 'Pred_Delta_FVC' vs 'True_Delta_FVC' with regression line
plt.figure(figsize=(8, 6))
sns.regplot(
    data=trend,
    x='True_Delta_FVC',
    y='Pred_Delta_FVC',
    scatter_kws={'alpha': 0.6, 'edgecolor': 'white'},
    line_kws={'color': 'red', 'linewidth': 2}
)
plt.title('Predicted vs True Delta FVC')
plt.xlabel('True Delta FVC [L]')
plt.ylabel('Predicted Delta FVC [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.show()

# %%
# plot distribution of 'True_Delta_FVC' and 'Pred_Delta_FVC' as histograms
plt.figure(figsize=(10, 6))
sns.histplot(
    data=trend,
    x='True_Delta_FVC',
    bins=40,
    color='#4C72B0',
    edgecolor='white',
    alpha=0.6,
    label='True Delta FVC'
)
sns.histplot(
    data=trend,
    x='Pred_Delta_FVC',
    bins=30,
    color='#DD8452',
    edgecolor='white',
    alpha=0.6,
    label='Predicted Delta FVC'
)
plt.title('Distribution of True vs Predicted Delta FVC')
plt.xlabel('Delta FVC [L]')
plt.ylabel('Number of Patients')
plt.legend()
plt.grid(alpha=0.1)
plt.tight_layout()
plt.show()

# %%
# plot 'Pred_Delta_FVC' vs 'True_Delta_FVC' with regression line
plt.figure(figsize=(8, 6))
sns.regplot(
    data=mismatch_trend,
    x='True_Delta_FVC',
    y='Pred_Delta_FVC',
    scatter_kws={'alpha': 0.6, 'edgecolor': 'white'},
    line_kws={'color': 'red', 'linewidth': 2}
)
plt.title('Predicted vs True Delta FVC for Mismatched Trends')
plt.xlabel('True Delta FVC [L]')
plt.ylabel('Predicted Delta FVC [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.show()

# %%
shap_df = pd.read_csv('/home/chanutem/OSIC_Analysis/cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/Explainability_Outputs_42_fold1_scaled/tabular_shap_importance_fixed_img0_seed42_2026-03-26_15-00-11.csv')

# %%
shap_df
# plot bar chart of mean absolute SHAP values for each feature
plt.figure(figsize=(10, 6))
sns.barplot(
    data=shap_df,
    x='Feature',
    y='MeanAbsSHAP',
    palette='Set2',
    edgecolor='white'
)
plt.title('Mean Absolute SHAP Values for Tabular Features') 
plt.xlabel('Feature')
plt.ylabel('Mean Absolute SHAP Value')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3, linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_4010109/1658842789.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## Multimodal performance

# %%
path_1 = '/home/chanutem/OSIC_Analysis/cv_multi_one_hot_5_cv_scaled_ES2026-04-02_09-52-03' 
path_2 = '/home/chanutem/OSIC_Analysis/cv_multi_one_hot_5_cv_scaled_ES2026-03-31_08-58-23'
path_3 = '/home/chanutem/OSIC_Analysis/cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47'

# %%
# load evaluation metrics for fold 1, seed 42 from each path
eval_1 = pd.read_csv(f'{path_1}/evaluation_metrics_seed42_fold1_multi_all_{path_1.split("_ES")[-1]}.csv') #remove ES from filename
eval_2 = pd.read_csv(f'{path_2}/evaluation_metrics_seed42_fold1_multi_all_{path_2.split("_ES")[-1]}.csv')
eval_3 = pd.read_csv(f'{path_3}/evaluation_metrics_seed42_fold1_multi_all_{path_3.split("_ES")[-1]}.csv')

# %%
#load all evaluation metrics for seed 42 from each path and concatenate into one dataframe
all_eval_1 = pd.DataFrame()
all_eval_2 = pd.DataFrame()
all_eval_3 = pd.DataFrame()
for fold in [1,2,3,4,5]:
    eval_1_fold = pd.read_csv(f'{path_1}/evaluation_metrics_seed42_fold{fold}_multi_all_{path_1.split("_ES")[-1]}.csv')
    eval_2_fold = pd.read_csv(f'{path_2}/evaluation_metrics_seed42_fold{fold}_multi_all_{path_2.split("_ES")[-1]}.csv')
    eval_3_fold = pd.read_csv(f'{path_3}/evaluation_metrics_seed42_fold{fold}_multi_all_{path_3.split("_ES")[-1]}.csv')
    all_eval_1 = pd.concat([all_eval_1, eval_1_fold], ignore_index=True) if 'all_eval_1' in locals() else eval_1_fold
    all_eval_2 = pd.concat([all_eval_2, eval_2_fold], ignore_index=True) if 'all_eval_2' in locals() else eval_2_fold
    all_eval_3 = pd.concat([all_eval_3, eval_3_fold], ignore_index=True) if 'all_eval_3' in locals() else eval_3_fold

# %%
#eval 3 -> lr=0,005, bs = 4, wd = 1e-7, patience = 22, hidden = 128 (MM-1)
#eval 2 -> lr=0.003, bs = 8, wd = 1e-7, patience = 20, hidden = 256  (MM-2)
#eval 1 -> lr=0.003, bs = 4, wd = 1e-7, patience = 20, hidden = 256 (MM-3)
all_eval_3
# Out:
#              Timestamp  Seed  Fold  Global_Fold  Batch_Size  Learning_Rate  \
# 0  2026-03-20_21-02-47    42     1            1           4          0.005
# 1  2026-03-20_21-02-47    42     2            2           4          0.005
# 2  2026-03-20_21-02-47    42     3            3           4          0.005
# 3  2026-03-20_21-02-47    42     4            4           4          0.005
# 4  2026-03-20_21-02-47    42     5            5           4          0.005
#
#    Weight_Decay  Early_Stopping_Patience  Total_Patients  Train_Samples  \
# 0  1.000000e-07                       22             556            377
# 1  1.000000e-07                       22             556            377
# 2  1.000000e-07                       22             556            378
# 3  1.000000e-07                       22             556            378
# 4  1.000000e-07                       22             556            378
#
#    Val_Samples  Test_Samples       MSE      RMSE       MAE  R2_Score  \
# ...

# %%
# plot R2 score for each fold and each path as boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(
    data=pd.concat([
        all_eval_3[['R2_Score']].assign(Model='MM-1'),
        all_eval_2[['R2_Score']].assign(Model='MM-2'),
        all_eval_1[['R2_Score']].assign(Model='MM-3')
    ], ignore_index=True),
    x='Model',
    y='R2_Score',
    palette='Set2',
    showmeans=True,
    meanprops={
        'marker': 'o',
        'markerfacecolor': 'white',
        'markeredgecolor': 'black',
        'markersize': 5   })
# Out:
# /tmp/ipykernel_4010109/1128619549.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# <Axes: xlabel='Model', ylabel='R2_Score'>

# %%
# scatter plot of R2 score for each fold and each path with regression line
plot_df = pd.concat([
    all_eval_3[['R2_Score']].assign(Model='MM-1'),
    all_eval_2[['R2_Score']].assign(Model='MM-2'),
    all_eval_1[['R2_Score']].assign(Model='MM-3')
], ignore_index=True)

# If Fold is not present in loaded CSVs, infer it by order within each model
if 'Fold' not in plot_df.columns:
    plot_df['Fold'] = plot_df.groupby('Model').cumcount() + 1

sns.stripplot(
    data=plot_df,
    x='Model',
    y='R2_Score',
    hue='Fold',
    palette='viridis',
    size=7,
    jitter=0.2,
    alpha=0.8,
    dodge=False
)
plt.legend(title='Fold', frameon=True)

# %%
# load validation metrics for seed 42 from each path and concatenate into one dataframe
all_val_1 = pd.DataFrame()
all_val_2 = pd.DataFrame()
all_val_3 = pd.DataFrame()
for fold in [1,2,3,4,5]:
    val_1_fold = pd.read_csv(f'{path_1}/validation_metrics_seed42_fold{fold}_multi_all_{path_1.split("_ES")[-1]}.csv')
    val_2_fold = pd.read_csv(f'{path_2}/validation_metrics_seed42_fold{fold}_multi_all_{path_2.split("_ES")[-1]}.csv')
    val_3_fold = pd.read_csv(f'{path_3}/validation_metrics_seed42_fold{fold}_multi_all_{path_3.split("_ES")[-1]}.csv')
    all_val_1 = pd.concat([all_val_1, val_1_fold], ignore_index=True) if 'all_val_1' in locals() else val_1_fold
    all_val_2 = pd.concat([all_val_2, val_2_fold], ignore_index=True) if 'all_val_2' in locals() else val_2_fold
    all_val_3 = pd.concat([all_val_3, val_3_fold], ignore_index=True) if 'all_val_3' in locals() else val_3_fold

# %%
all_val_3['Best_Model_Path'].to_list()
# Out:
# ['cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/best_model_seed42_fold1_lr_multi_all_2026-03-20_21-02-47.pth',
#  'cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/best_model_seed42_fold2_lr_multi_all_2026-03-20_21-02-47.pth',
#  'cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/best_model_seed42_fold3_lr_multi_all_2026-03-20_21-02-47.pth',
#  'cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/best_model_seed42_fold4_lr_multi_all_2026-03-20_21-02-47.pth',
#  'cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/best_model_seed42_fold5_lr_multi_all_2026-03-20_21-02-47.pth']

# %%
# plot R2 score for each fold and each path as boxplot
plt.figure(figsize=(8, 6))
sns.boxplot(
    data=pd.concat([
        all_val_3[['R2_Score']].assign(Model='MM-1'),
        all_val_2[['R2_Score']].assign(Model='MM-2'),
        all_val_1[['R2_Score']].assign(Model='MM-3')
    ], ignore_index=True),
    x='Model',
    y='R2_Score',
    palette='Set2',
    showmeans=True,
    meanprops={
        'marker': 'o',
        'markerfacecolor': 'white',
        'markeredgecolor': 'black',
        'markersize': 5   })
# Out:
# /tmp/ipykernel_4010109/1900849016.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# <Axes: xlabel='Model', ylabel='R2_Score'>

# %%
# scatter plot of R2 score for each fold and each path with regression line
plot_data = pd.concat([
    all_eval_3[['R2_Score', 'Fold']].assign(Model='MM-1'),
    all_eval_2[['R2_Score', 'Fold']].assign(Model='MM-2'),
    all_eval_1[['R2_Score', 'Fold']].assign(Model='MM-3')
    
], ignore_index=True)
mean_mm1 = plot_data[plot_data['Model'] == 'MM-1']['R2_Score'].mean()
mean_mm2 = plot_data[plot_data['Model'] == 'MM-2']['R2_Score'].mean()
mean_mm3 = plot_data[plot_data['Model'] == 'MM-3']['R2_Score'].mean()
plt.axhline(mean_mm1, color='#EA5A26', linestyle='--', linewidth=1.2, label=f'MM-1 Mean: {mean_mm1:.3f}')
plt.axhline(mean_mm2, color='#6D9BE6', linestyle='--', linewidth=1.2, label=f'MM-2 Mean: {mean_mm2:.3f}')
plt.axhline(mean_mm3, color='#6EB670', linestyle='--', linewidth=1.2, label=f'MM-3 Mean: {mean_mm3:.3f}')
# colour palette to have same colour for each model across boxplot and stripplot
palette = {'MM-1': "#EA5A26", 'MM-2': "#6D9BE6", 'MM-3': "#6EB670"}
sns.stripplot(
    data=plot_data,
    x='Model',
    y='R2_Score',
    #hue='Fold',
    palette=palette,
    size=7,
    jitter=0.2,
    alpha=0.8,
    dodge=False
)
plt.legend( frameon=True) #title='Fold',
#plt.title('R2 Score Comparison Across Hyperparameter Configurations')
plt.xlabel('Model Configuration')
plt.ylabel('R2 Score')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'mm_hyperparameter_comparison_r2_score.png'), dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_4010109/960701618.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(

# %% [markdown]
# ## Image Only Performance

# %%
path_image_model = 'cv_image_only_5_cv'
time_1 = '2026-04-03_21-07-05'
time_2 = '2026-03-20_09-45-24'
time_3 = '2026-04-08_17-37-25'
time_4 = '2026-04-09_09-46-35'

# %%
# load evalation metrics for image-only model with seed 42 for both time points with all folds 
eval_image_1 = pd.DataFrame()
eval_image_2 = pd.DataFrame()
eval_image_3 = pd.DataFrame()
eval_image_4 = pd.DataFrame()
for fold in [1,2,3,4,5]:
    eval_image_1_fold = pd.read_csv(f'/home/chanutem/OSIC_Analysis/{path_image_model}/evaluation_metrics_seed42_fold{fold}_image_only_{time_1}.csv')
    eval_image_2_fold = pd.read_csv(f'{path_image_model}/evaluation_metrics_seed42_fold{fold}_image_only_{time_2}.csv')
    eval_image_3_fold = pd.read_csv(f'{path_image_model}/evaluation_metrics_seed42_fold{fold}_image_only_{time_3}.csv')
    eval_image_4_fold = pd.read_csv(f'{path_image_model}/evaluation_metrics_seed42_fold{fold}_image_only_{time_4}.csv')
    eval_image_1 = pd.concat([eval_image_1, eval_image_1_fold], ignore_index=True) if 'eval_image_1' in locals() else eval_image_1_fold
    eval_image_2 = pd.concat([eval_image_2, eval_image_2_fold], ignore_index=True) if 'eval_image_2' in locals() else eval_image_2_fold
    eval_image_3 = pd.concat([eval_image_3, eval_image_3_fold], ignore_index=True) if 'eval_image_3' in locals() else eval_image_3_fold
    eval_image_4 = pd.concat([eval_image_4, eval_image_4_fold], ignore_index=True) if 'eval_image_4' in locals() else eval_image_3_fold

# %%
eval_image_4['Best_Model_Path'].to_list()
# Out:
# ['cv_image_only_5_cv/best_model_seed42_fold1_lr_image_only_2026-04-09_09-46-35.pth',
#  'cv_image_only_5_cv/best_model_seed42_fold2_lr_image_only_2026-04-09_09-46-35.pth',
#  'cv_image_only_5_cv/best_model_seed42_fold3_lr_image_only_2026-04-09_09-46-35.pth',
#  'cv_image_only_5_cv/best_model_seed42_fold4_lr_image_only_2026-04-09_09-46-35.pth',
#  'cv_image_only_5_cv/best_model_seed42_fold5_lr_image_only_2026-04-09_09-46-35.pth']

# %%
eval_image_3 #linear head with stronger regulation
eval_image_4 # MLP head higher dropout and stronger weight decay
# Out:
#              Timestamp  Seed  Fold  Global_Fold  Batch_Size  Learning_Rate  \
# 0  2026-04-09_09-46-35    42     1            1           3        0.00003
# 1  2026-04-09_09-46-35    42     2            2           3        0.00003
# 2  2026-04-09_09-46-35    42     3            3           3        0.00003
# 3  2026-04-09_09-46-35    42     4            4           3        0.00003
# 4  2026-04-09_09-46-35    42     5            5           3        0.00003
#
#    Weight_Decay  Early_Stopping_Patience  Total_Patients  Train_Samples  \
# 0         0.001                       15             556            377
# 1         0.001                       15             556            377
# 2         0.001                       15             556            378
# 3         0.001                       15             556            378
# 4         0.001                       15             556            378
#
#    Val_Samples  Test_Samples       MSE      RMSE       MAE  R2_Score  \
# ...

# %%
# plot R2 score for image-only model for both time points as boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=pd.concat([
        eval_image_1[['R2_Score']].assign(Model='MLP-Head'),
        eval_image_2[['R2_Score']].assign(Model='Linear-Head'),
        eval_image_3[['R2_Score']].assign(Model='Linear-Head +  Regulation'),
        eval_image_4[['R2_Score']].assign(Model='MLP-Head +  Regulation')
    ]),
    x='Model',
    y='R2_Score'
)
plt.title('R2 Score for Image-Only Model')
plt.show()

# %%
# scarter plot of R2 score for image-only model for both time points with regression line
plot_data = pd.concat([
    eval_image_1[['R2_Score', 'Fold']].assign(Model='MLP-Head'),
    eval_image_4[['R2_Score','Fold']].assign(Model='MLP-Head + Reg'),
    eval_image_2[['R2_Score', 'Fold']].assign(Model='Linear-Head'),
    eval_image_3[['R2_Score', 'Fold']].assign(Model='Linear-Head + Reg')

], ignore_index=True)  
# add mean line for each model
mean_image_1 = eval_image_1['R2_Score'].mean()
mean_image_2 = eval_image_2['R2_Score'].mean()
mean_image_3 = eval_image_3['R2_Score'].mean()
mean_image_4 = eval_image_4['R2_Score'].mean()

std_image_1 = eval_image_1['R2_Score'].std()
std_image_2 = eval_image_2['R2_Score'].std()
std_image_3 = eval_image_3['R2_Score'].std()
std_image_4 = eval_image_4['R2_Score'].std()



plt.figure(figsize=(10,5))
plt.axhline(
    mean_image_1,
    color='#1C4FA1',
    linestyle='--',
    linewidth=1.2,
    label=f'MLP-Head Mean: {mean_image_1:.3f}+- {std_image_1:.3f}'
)

plt.axhline(
    mean_image_4,
    color='#56A4B2',
    linestyle='--',
    linewidth=1.2,
    label=f'MLP-Head + Reg Mean: {mean_image_4:.3f}+- {std_image_4:.3f}'
)

plt.axhline(
    mean_image_2,
    color='green',
    linestyle='--',
    linewidth=1.2,
    label=f'Linear-Head Mean: {mean_image_2:.3f}+- {std_image_2:.3f}'
)
plt.axhline(
    mean_image_3,
    color='red',
    linestyle='--',
    linewidth=1.2,
    label=f'Linear-Head + Stronger Regulation Mean: {mean_image_3:.3f} +- {std_image_3:.3f}'
)
palette = {'MLP-Head': "#1C4FA1", 'MLP-Head + Reg': "#56A4B2",'Linear-Head': "green", 'Linear-Head + Reg': "red"}
sns.stripplot(
    data=plot_data,
    x='Model',
    y='R2_Score',
    #hue='Fold',
    palette=palette,
    size=7,
    jitter=0.2,
    alpha=0.8,
    dodge=False
)
plt.legend( frameon=True) # title='Fold',
plt.title('R2 Score for Image-Only Model Across Folds')
plt.xlabel('Model Configuration')
plt.ylabel('R2 Score')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'image_model_r2_comparison.pdf'), dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_4010109/4053023839.py:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(

# %%
# print statistic of performance
print("Image-Only Model Performance:")
eval_image_1[['Fold','R2_Score','MSE']].mean()
# Out:
# Image-Only Model Performance:
# Fold        3.000000
# R2_Score    0.302671
# MSE         0.492057
# dtype: float64

# %%
# load and compare validation loss cv_image_only_5_cv/validation_metrics_seed42_fold5_image_only_{time}.csv
val_image_1 = pd.DataFrame()
val_image_2 = pd.DataFrame()
val_image_3 = pd.DataFrame()
val_image_4 = pd.DataFrame()    

for fold in [1,2,3,4,5]:
    val_image_1_fold = pd.read_csv(f'/home/chanutem/OSIC_Analysis/{path_image_model}/validation_metrics_seed42_fold{fold}_image_only_{time_1}.csv')
    val_image_2_fold = pd.read_csv(f'{path_image_model}/validation_metrics_seed42_fold{fold}_image_only_{time_2}.csv')
    val_image_3_fold = pd.read_csv(f'{path_image_model}/validation_metrics_seed42_fold{fold}_image_only_{time_3}.csv')
    val_image_4_fold = pd.read_csv(f'{path_image_model}/validation_metrics_seed42_fold{fold}_image_only_{time_4}.csv')
    val_image_1 = pd.concat([val_image_1, val_image_1_fold], ignore_index=True) if 'val_image_1' in locals() else val_image_1_fold
    val_image_2 = pd.concat([val_image_2, val_image_2_fold], ignore_index=True) if 'val_image_2' in locals() else val_image_2_fold
    val_image_3 = pd.concat([val_image_3, val_image_3_fold], ignore_index=True) if 'val_image_3' in locals() else val_image_3_fold
    val_image_4 = pd.concat([val_image_4, val_image_4_fold], ignore_index=True) if 'val_image_4' in locals() else val_image_4_fold

# %%
# plot R2 score for image-only model for both time points as boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(
    data=pd.concat([
        val_image_1[['Best_Val_Loss']].assign(Model='MLP-Head'),
        val_image_2[['Best_Val_Loss']].assign(Model='Linear-Head'),
        val_image_3[['Best_Val_Loss']].assign(Model='Linear-Head +  Regulation'),
        val_image_4[['Best_Val_Loss']].assign(Model='MLP-Head +  Regulation')
    ]),
    x='Model',
    y='Best_Val_Loss'
)
plt.title('Best Validation Loss for Image-Only Model')
plt.show()

# %%
# scarter plot of R2 score for image-only model for both time points with regression line for validation
plot_data = pd.concat([
    val_image_1[['R2_Score', 'Fold']].assign(Model='MLP-Head'),
    val_image_4[['R2_Score','Fold']].assign(Model='MLP-Head + Reg'),
    val_image_2[['R2_Score', 'Fold']].assign(Model='Linear-Head'),
    val_image_3[['R2_Score', 'Fold']].assign(Model='Linear-Head + Reg')

], ignore_index=True)  
# add mean line for each model
mean_image_1 = val_image_1['R2_Score'].mean()
mean_image_2 = val_image_2['R2_Score'].mean()
mean_image_3 = val_image_3['R2_Score'].mean()
mean_image_4 = val_image_4['R2_Score'].mean()
plt.figure(figsize=(10,5))
plt.axhline(
    mean_image_1,
    color='#1C4FA1',
    linestyle='--',
    linewidth=1.2,
    label=f'MLP-Head Mean: {mean_image_1:.3f}'
)

plt.axhline(
    mean_image_4,
    color='#56A4B2',
    linestyle='--',
    linewidth=1.2,
    label=f'MLP-Head + Reg Mean: {mean_image_4:.3f}'
)

plt.axhline(
    mean_image_2,
    color='green',
    linestyle='--',
    linewidth=1.2,
    label=f'Linear-Head Mean: {mean_image_2:.3f}'
)
plt.axhline(
    mean_image_3,
    color='red',
    linestyle='--',
    linewidth=1.2,
    label=f'Linear-Head + Stronger Regulation Mean: {mean_image_3:.3f}'
)
palette = {'MLP-Head': "#1C4FA1", 'MLP-Head + Reg': "#56A4B2",'Linear-Head': "green", 'Linear-Head + Reg': "red"}
sns.stripplot(
    data=plot_data,
    x='Model',
    y='R2_Score',
    #hue='Fold',
    palette=palette,
    size=7,
    jitter=0.2,
    alpha=0.8,
    dodge=False
)
plt.legend( frameon=True) # title='Fold',
plt.title('R2 Score for Image-Only Model Across Folds')
plt.xlabel('Model Configuration')
plt.ylabel('R2 Score')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'image_model_r2_comparison.pdf'), dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_4010109/3254176505.py:46: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(

# %% [markdown]
# ## All in one

# %%
# Full data (used for mean lines + legend)
plot_all = pd.concat([
    eval_image_1[['R2_Score']].assign(Model='Image-Only (MLP-Head)'),
    eval_image_2[['R2_Score']].assign(Model='Image-Only (Linear-Head)'),
    all_eval_3[['R2_Score']].assign(Model='Multimodal (MM-1)'),
    all_eval_2[['R2_Score']].assign(Model='Multimodal (MM-2)'),
    all_eval_1[['R2_Score']].assign(Model='Multimodal (MM-3)'),
    test_metrics_df_mlp[['R2_Score']].assign(Model='Tabular MLP'),
    test_metrics_df_rf[['R2_Score']].assign(Model='Random Forest')
], ignore_index=True)

# Points to display (exclude image-only)
plot_points = plot_all[~plot_all['Model'].str.startswith('Image-Only')]

model_colors = {
    'Image-Only (MLP-Head)': '#1C4FA1',
    'Image-Only (Linear-Head)': 'green',
    'Multimodal (MM-3)': "#EA5A26",
    'Multimodal (MM-2)': "#6D9BE6",
    'Multimodal (MM-1)': "#6EB670",
    'Tabular MLP': 'purple',
    'Random Forest': 'orange'
}

plt.figure(figsize=(12, 5))

# Mean lines for ALL models (including image-only)
mean_values = plot_all.groupby('Model')['R2_Score'].mean()
std_values = plot_all.groupby('Model')['R2_Score'].std()
mean_handles = []
for model, mean_val in mean_values.items():
    h = plt.axhline(
        mean_val,
        linestyle='--',
        linewidth=1.2,
        color=model_colors[model],
        label=f'{model} Mean: {mean_val:.3f} ± {std_values[model]:.3f}'
    )
    mean_handles.append(h)

# Strip plot without image-only points
ax = sns.stripplot(
    data=plot_points,
    x='Model',
    y='R2_Score',
    hue='Model',
    palette=model_colors,
    size=7,
    jitter=0.2,
    alpha=0.8,
    dodge=False
)

# Remove stripplot legend, keep only mean legend
if ax.get_legend() is not None:
    ax.get_legend().remove()
#plt.legend(handles=mean_handles, frameon=True, bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12)

#plt.title('R2 Score Comparison Across Models')
plt.ylim(0.79, 0.89)  # image-only means stay in legend even if outside this y-range
plt.xlabel('Model')
plt.ylabel('R2 Score')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'model_comparison_r2_score.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
plot_all = pd.concat([
    eval_image_1[['R2_Score', 'MSE', 'RMSE', 'MAE']].assign(Model='Image-Only (MLP-Head)'),
    eval_image_2[['R2_Score', 'MSE', 'RMSE', 'MAE']].assign(Model='Image-Only (Linear-Head)'),
    all_eval_3[['R2_Score', 'MSE', 'RMSE', 'MAE']].assign(Model='Multimodal (MM-1)'),
    all_eval_2[['R2_Score', 'MSE', 'RMSE', 'MAE']].assign(Model='Multimodal (MM-2)'),
    all_eval_1[['R2_Score', 'MSE', 'RMSE', 'MAE']].assign(Model='Multimodal (MM-3)'),
    test_metrics_df_mlp[['R2_Score', 'MSE', 'RMSE', 'MAE']].assign(Model='Tabular MLP'),
    test_metrics_df_rf[['R2_Score', 'MSE', 'RMSE', 'MAE']].assign(Model='Random Forest')
], ignore_index=True)

# %%
all_eval_1['Best_Model_Path'].to_list()
# Out:
# ['cv_multi_one_hot_5_cv_scaled_ES2026-04-02_09-52-03/best_model_seed42_fold1_lr_multi_all_2026-04-02_09-52-03.pth',
#  'cv_multi_one_hot_5_cv_scaled_ES2026-04-02_09-52-03/best_model_seed42_fold2_lr_multi_all_2026-04-02_09-52-03.pth',
#  'cv_multi_one_hot_5_cv_scaled_ES2026-04-02_09-52-03/best_model_seed42_fold3_lr_multi_all_2026-04-02_09-52-03.pth',
#  'cv_multi_one_hot_5_cv_scaled_ES2026-04-02_09-52-03/best_model_seed42_fold4_lr_multi_all_2026-04-02_09-52-03.pth',
#  'cv_multi_one_hot_5_cv_scaled_ES2026-04-02_09-52-03/best_model_seed42_fold5_lr_multi_all_2026-04-02_09-52-03.pth']

# %%
# performance statistics for each model
for model in plot_all['Model'].unique():
    model_r2 = plot_all[plot_all['Model'] == model]['R2_Score']
    model_mse = plot_all[plot_all['Model'] == model]['MSE'] 
    model_rmse = plot_all[plot_all['Model'] == model]['RMSE']
    model_mae = plot_all[plot_all['Model'] == model]['MAE']
    mean_val = model_r2.mean()
    mean_mse = model_mse.mean()
    mean_rmse = model_rmse.mean()
    mean_mae = model_mae.mean()
    std_mse = model_mse.std()
    std_rmse = model_rmse.std()
    std_mae = model_mae.std()
    std_val = model_r2.std()
    print(f"{model}: Mean MSE = {mean_mse:.3f} ± {std_mse:.3f}")
    print(f"{model}: Mean RMSE = {mean_rmse:.3f} ± {std_rmse:.3f}")
    print(f"{model}: Mean MAE = {mean_mae:.3f} ± {std_mae:.3f}")
    print(f"{model}: Mean R2 Score = {mean_val:.3f}, Std = {std_val:.3f}")
# Out:
# Image-Only (MLP-Head): Mean MSE = 0.492 ± 0.017
# Image-Only (MLP-Head): Mean RMSE = 0.701 ± 0.012
# Image-Only (MLP-Head): Mean MAE = 0.544 ± 0.009
# Image-Only (MLP-Head): Mean R2 Score = 0.303, Std = 0.024
# Image-Only (Linear-Head): Mean MSE = 0.464 ± 0.023
# Image-Only (Linear-Head): Mean RMSE = 0.681 ± 0.017
# Image-Only (Linear-Head): Mean MAE = 0.534 ± 0.014
# Image-Only (Linear-Head): Mean R2 Score = 0.343, Std = 0.032
# Multimodal (MM-1): Mean MSE = 0.110 ± 0.011
# Multimodal (MM-1): Mean RMSE = 0.332 ± 0.017
# Multimodal (MM-1): Mean MAE = 0.243 ± 0.016
# Multimodal (MM-1): Mean R2 Score = 0.844, Std = 0.016
# Multimodal (MM-2): Mean MSE = 0.120 ± 0.015
# Multimodal (MM-2): Mean RMSE = 0.345 ± 0.022
# Multimodal (MM-2): Mean MAE = 0.252 ± 0.016
# Multimodal (MM-2): Mean R2 Score = 0.831, Std = 0.022
# Multimodal (MM-3): Mean MSE = 0.104 ± 0.013
# Multimodal (MM-3): Mean RMSE = 0.323 ± 0.019
# Multimodal (MM-3): Mean MAE = 0.236 ± 0.022
# ...

# %% [markdown]
# ## Select patient for XAI

# %%
# load prediction cv_image_only_5_cv/2026-03-20_09-45-24_pred/predictions_fold1.csv
for fold in [1,2,3,4,5]:
    globals()[f'pred_image_2_fold_{fold}'] = pd.read_csv(f'{path_image_model}/2026-03-20_09-45-24_pred/predictions_fold{fold}.csv')

# %%
pred_image_2_fold_1
# Out:
#     PatientID  Predicted_FVC
# 0     1001100       2.525122
# 1      894746       2.995931
# 2      469929       3.225957
# 3     1000842       1.591781
# 4      781116       2.255624
# ..        ...            ...
# 79    1001268       1.821440
# 80     930434       3.663750
# 81    1000468       2.432294
# 82    1000758       2.209551
# 83    1000952       2.012164
#
# [84 rows x 2 columns]

# %%
# load test patient
test_patient= pd.read_csv('Patient_Splits_Seed42/test_patients.csv')

# %%
cases_df = pd.read_csv('cleaned_collected_cases_final_with_FEV1.csv')

test_cases_df = cases_df[cases_df['PatientID'].isin(test_patient['PatientID'])]
test_cases_df
# Count per diagnosis
diagnosis_counts = test_cases_df['Primary Diagnosis'].value_counts()
print(diagnosis_counts)
# Out:
# Primary Diagnosis
# CTD-ILD    34
# IPF        32
# UILD       11
# Other       4
# CHP         3
# Name: count, dtype: int64

# %%
# add prediction to test_cases_df
test_cases_df = test_cases_df.merge(pred_image_2_fold_1, on='PatientID', how='left')
# rename Predicted_FVC to Predicted_FVC_f1
test_cases_df = test_cases_df.rename(columns={'Predicted_FVC': 'Predicted_FVC_f1'})
test_cases_df
# same for rest of the folds
test_cases_df = test_cases_df.merge(pred_image_2_fold_2[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_f2'}), on='PatientID', how='left')
test_cases_df = test_cases_df.merge(pred_image_2_fold_3[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_f3'}), on='PatientID', how='left')
test_cases_df = test_cases_df.merge(pred_image_2_fold_4[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_f4'}), on='PatientID', how='left')  
test_cases_df = test_cases_df.merge(pred_image_2_fold_5[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_f5'}), on='PatientID', how='left')  
test_cases_df
# Out:
#     PatientID BaselineDate                                          SeriesUID  \
# 0      727988   1970-10-05  1.2.392.200036.9116.2.6.1.3268.2047398422.1581...
# 1     1000590   1947-01-01  1.2.826.0.1.3680043.10.1218.842605194965467296...
# 2     1000945   1967-01-01  1.2.826.0.1.3680043.10.1218.105219383145758704...
# 3     1001377   1964-01-01  1.2.826.0.1.3680043.10.1218.637683879195636365...
# 4     1000668   1972-12-01  1.2.826.0.1.3680043.10.1218.739059456245798297...
# ..        ...          ...                                                ...
# 79     687751   1981-09-21  1.2.392.200036.9116.2.6.1.3268.2047398422.1488...
# 80    1001148   1979-01-01  1.2.826.0.1.3680043.10.1218.208404350996892455...
# 81     958729   1952-10-27  1.2.840.113619.2.55.3.1024080006.349.151380960...
# 82    1001041   1962-01-01  1.2.826.0.1.3680043.10.1218.171544478993440844...
# 83     884616   1973-10-01            1.2.840.113704.1.111.5736.1296042285.14
#
# ...

# %%
# statistics of predicted FVC across folds
pred_cols = [col for col in test_cases_df.columns if col.startswith('Predicted_FVC')]
test_cases_df['Predicted_FVC_Mean'] = test_cases_df[pred_cols].mean(axis=1)
test_cases_df['Predicted_FVC_Std'] = test_cases_df[pred_cols].std(axis=1)
test_cases_df[['PatientID', 'Followup FVC Volume L', 'Predicted_FVC_Mean', 'Predicted_FVC_Std']]
#plot predicted FVC mean vs true FVC with error bars for std
plt.figure(figsize=(8, 6))
plt.errorbar(
    test_cases_df['Followup FVC Volume L'],
    test_cases_df['Predicted_FVC_Mean'],
    yerr=test_cases_df['Predicted_FVC_Std'],
    fmt='o',
    ecolor='lightgray',
    elinewidth=2,
    capsize=0
)
plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
#plt.title('Predicted FVC vs True FVC with Error Bars')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.legend(['Perfect Prediction', 'Mean Predicted FVC with Std Dev'])
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'image_only_predicted_vs_true_fvc_with_error_bars.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# statistics of predicted FVC across folds depending on diagnosis
diagnosis_stats = test_cases_df.groupby('Primary Diagnosis').agg({
    'Followup FVC Volume L': ['mean', 'std'],
    'Predicted_FVC_Mean': ['mean', 'std'],
    'Predicted_FVC_Std': ['mean', 'std']
})
#print(diagnosis_stats)

#plot predicted FVC mean vs true FVC with error bars for std for each diagnosis
diagnoses = test_cases_df['Primary Diagnosis'].unique()
plt.figure(figsize=(12, 8))
for diagnosis in diagnoses:
    subset = test_cases_df[test_cases_df['Primary Diagnosis'] == diagnosis]
    plt.errorbar(
        subset['Followup FVC Volume L'],
        subset['Predicted_FVC_Mean'],
        yerr=subset['Predicted_FVC_Std'],
        fmt='o',
        label=diagnosis,
        alpha=0.7
    )
plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
plt.title('Predicted FVC vs True FVC with Error Bars by Diagnosis')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.legend(title='Primary Diagnosis')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'image_only_predicted_vs_true_fvc_by_diagnosis.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# plot by smocking history
smoking_stats = test_cases_df.groupby('Smoking History').agg({
    'Followup FVC Volume L': ['mean', 'std'],
    'Predicted_FVC_Mean': ['mean', 'std'],
    'Predicted_FVC_Std': ['mean', 'std']
})
#print(smoking_stats)
# plot predicted FVC mean vs true FVC with error bars for std for each smoking history
smoking_histories = test_cases_df['Smoking History'].unique()
plt.figure(figsize=(12, 8))
for history in smoking_histories:   
    subset = test_cases_df[test_cases_df['Smoking History'] == history]
    plt.errorbar(
        subset['Followup FVC Volume L'],
        subset['Predicted_FVC_Mean'],
        yerr=subset['Predicted_FVC_Std'],
        fmt='o',
        label=history,
        alpha=0.7
    )
plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
plt.title('Predicted FVC vs True FVC with Error Bars by Smoking History')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.legend(title='Smoking History')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'image_only_predicted_vs_true_fvc_by_smoking_history.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# plot of statistics of predicted FVC across folds depending on delta FVC
# stat coulored by delta FVC (column delta fvc already exists in test_cases_df as 'Delta FVC')
plt.figure(figsize=(8, 6))

plt.errorbar(
    test_cases_df['Followup FVC Volume L'],
    test_cases_df['Predicted_FVC_Mean'],
    yerr=test_cases_df['Predicted_FVC_Std'],
    fmt='none',
    ecolor='lightgray',
    elinewidth=1,
    alpha=0.7,
    capsize=0,
    zorder=1
)

scatter = plt.scatter(
    test_cases_df['Followup FVC Volume L'],
    test_cases_df['Predicted_FVC_Mean'],
    c=test_cases_df['Delta FVC'],
    cmap='viridis',
    alpha=0.8,
    edgecolor='white',
    zorder=2
)

plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
plt.title('Image-Only Model: Predicted FVC vs True FVC Colored by Delta FVC')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.colorbar(scatter, label='Delta FVC [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'image_only_predicted_vs_true_fvc_by_delta_fvc.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
## print highest error cases for image-only model
test_cases_df['Absolute_Error'] = abs(test_cases_df['Followup FVC Volume L'] - test_cases_df['Predicted_FVC_Mean'])
test_cases_df.sort_values('Absolute_Error', ascending=True)[['PatientID', 'Followup FVC Volume L', 'Predicted_FVC_Mean', 'Absolute_Error', 'Primary Diagnosis', 'Smoking History', 'Delta FVC']].head(10)
# Out:
#     PatientID  Followup FVC Volume L  Predicted_FVC_Mean  Absolute_Error  \
# 82    1001041                   1.65            1.649548        0.000452
# 38    1000901                   2.33            2.345041        0.015041
# 23    1000988                   1.92            1.903621        0.016379
# 2     1000945                   1.58            1.555086        0.024914
# 69    1001100                   2.66            2.686284        0.026284
# 76     492401                   2.82            2.792977        0.027023
# 33     529261                   1.84            1.876253        0.036253
# 17    1001310                   1.70            1.740025        0.040025
# 56    1000639                   2.48            2.435965        0.044035
# 75    1001253                   1.49            1.545868        0.055868
#
#    Primary Diagnosis Smoking History  Delta FVC
# 82           CTD-ILD       Ex Smoker       0.39
# 38               CHP    Never Smoker      -0.04
# ...

# %% [markdown]
# 1001268, 666234 - bad

# %% [markdown]
# ### plot MM pred

# %%
# multimodal predictions cv_multi_one_hot_5_cv_scaled_ES2026-04-02_09-52-03/2026-04-02_09-52-03_pred
for fold in [1,2,3,4,5]:
    globals()[f'pred_mm_3_fold_{fold}'] = pd.read_csv(f'{path_1}/2026-04-02_09-52-03_pred/predictions_fold{fold}.csv')

# %%
#cv_multi_one_hot_5_cv_scaled_ES2026-03-20_21-02-47/2026-03-20_21-02-47_pred/predictions_fold1.csv
for fold in [1,2,3,4,5]:
    globals()[f'pred_mm_1_fold_{fold}'] = pd.read_csv(f'{path_3}/2026-03-20_21-02-47_pred/predictions_fold{fold}.csv')

# %%
pred_mm_1_fold_1
# Out:
#     PatientID  Baseline_FVC  True_FVC  Predicted_FVC  Residual_True_minus_Pred
# 0     1001100          3.50      2.66       3.256422                 -0.596422
# 1      894746          4.01      4.19       3.736414                  0.453586
# 2      469929          3.83      3.79       3.231538                  0.558462
# 3     1000842          1.55      1.73       1.564343                  0.165657
# 4      781116          2.29      2.26       2.471024                 -0.211024
# ..        ...           ...       ...            ...                       ...
# 79    1001268          3.59      3.88       3.304048                  0.575952
# 80     930434          3.91      3.93       3.831674                  0.098326
# 81    1000468          2.20      2.50       2.325062                  0.174938
# 82    1000758          1.84      1.67       1.647508                  0.022492
# 83    1000952          3.83      3.69       3.592973                  0.097027
#
# [84 rows x 5 columns]

# %%
test_cases_df = test_cases_df.merge(pred_mm_3_fold_1[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM3_f1'}), on='PatientID', how='left')
test_cases_df = test_cases_df.merge(pred_mm_3_fold_2[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM3_f2'}), on='PatientID', how='left')  
test_cases_df = test_cases_df.merge(pred_mm_3_fold_3[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM3_f3'}), on='PatientID', how='left')  
test_cases_df = test_cases_df.merge(pred_mm_3_fold_4[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM3_f4'}), on='PatientID', how='left')  
test_cases_df = test_cases_df.merge(pred_mm_3_fold_5[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM3_f5'}), on='PatientID', how='left')  
test_cases_df
# Out:
#     PatientID BaselineDate                                          SeriesUID  \
# 0      727988   1970-10-05  1.2.392.200036.9116.2.6.1.3268.2047398422.1581...
# 1     1000590   1947-01-01  1.2.826.0.1.3680043.10.1218.842605194965467296...
# 2     1000945   1967-01-01  1.2.826.0.1.3680043.10.1218.105219383145758704...
# 3     1001377   1964-01-01  1.2.826.0.1.3680043.10.1218.637683879195636365...
# 4     1000668   1972-12-01  1.2.826.0.1.3680043.10.1218.739059456245798297...
# ..        ...          ...                                                ...
# 79     687751   1981-09-21  1.2.392.200036.9116.2.6.1.3268.2047398422.1488...
# 80    1001148   1979-01-01  1.2.826.0.1.3680043.10.1218.208404350996892455...
# 81     958729   1952-10-27  1.2.840.113619.2.55.3.1024080006.349.151380960...
# 82    1001041   1962-01-01  1.2.826.0.1.3680043.10.1218.171544478993440844...
# 83     884616   1973-10-01            1.2.840.113704.1.111.5736.1296042285.14
#
# ...

# %%
## add multimodal predictions to test_cases_df
test_cases_df = test_cases_df.merge(pred_mm_1_fold_1[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM1_f1'}), on='PatientID', how='left')
test_cases_df = test_cases_df.merge(pred_mm_1_fold_2[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM1_f2'}), on='PatientID', how='left')  
test_cases_df = test_cases_df.merge(pred_mm_1_fold_3[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM1_f3'}), on='PatientID', how='left')  
test_cases_df = test_cases_df.merge(pred_mm_1_fold_4[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM1_f4'}), on='PatientID', how='left')  
test_cases_df = test_cases_df.merge(pred_mm_1_fold_5[['PatientID', 'Predicted_FVC']].rename(columns={'Predicted_FVC': 'Predicted_FVC_MM1_f5'}), on='PatientID', how='left')  
test_cases_df
# Out:
#     PatientID BaselineDate                                          SeriesUID  \
# 0      727988   1970-10-05  1.2.392.200036.9116.2.6.1.3268.2047398422.1581...
# 1     1000590   1947-01-01  1.2.826.0.1.3680043.10.1218.842605194965467296...
# 2     1000945   1967-01-01  1.2.826.0.1.3680043.10.1218.105219383145758704...
# 3     1001377   1964-01-01  1.2.826.0.1.3680043.10.1218.637683879195636365...
# 4     1000668   1972-12-01  1.2.826.0.1.3680043.10.1218.739059456245798297...
# ..        ...          ...                                                ...
# 79     687751   1981-09-21  1.2.392.200036.9116.2.6.1.3268.2047398422.1488...
# 80    1001148   1979-01-01  1.2.826.0.1.3680043.10.1218.208404350996892455...
# 81     958729   1952-10-27  1.2.840.113619.2.55.3.1024080006.349.151380960...
# 82    1001041   1962-01-01  1.2.826.0.1.3680043.10.1218.171544478993440844...
# 83     884616   1973-10-01            1.2.840.113704.1.111.5736.1296042285.14
#
# ...

# %%
# statistics of predicted FVC across folds
pred_cols = [col for col in test_cases_df.columns if col.startswith('Predicted_FVC_MM1')]
test_cases_df['Predicted_FVC_MM1_Mean'] = test_cases_df[pred_cols].mean(axis=1)
test_cases_df['Predicted_FVC_MM1_Std'] = test_cases_df[pred_cols].std(axis=1)
test_cases_df[['PatientID', 'Followup FVC Volume L', 'Predicted_FVC_MM1_Mean', 'Predicted_FVC_MM1_Std']]
# same for mm3
pred_cols_mm3 = [col for col in test_cases_df.columns if col.startswith('Predicted_FVC_MM3')]
test_cases_df['Predicted_FVC_MM3_Mean'] = test_cases_df[pred_cols_mm3].mean(axis=1)
test_cases_df['Predicted_FVC_MM3_Std'] = test_cases_df[pred_cols_mm3].std(axis=1)
test_cases_df[['PatientID', 'Followup FVC Volume L', 'Predicted_FVC_MM3_Mean', 'Predicted_FVC_MM3_Std']]
# Out:
#     PatientID  Followup FVC Volume L  Predicted_FVC_MM3_Mean  \
# 0      727988                   2.23                2.376488
# 1     1000590                   2.70                2.932341
# 2     1000945                   1.58                1.680351
# 3     1001377                   2.65                2.586232
# 4     1000668                   2.06                2.049985
# ..        ...                    ...                     ...
# 79     687751                   2.39                2.513365
# 80    1001148                   2.25                2.225018
# 81     958729                   2.36                2.452774
# 82    1001041                   1.65                1.362223
# 83     884616                   2.40                2.598777
#
#     Predicted_FVC_MM3_Std
# 0                0.144829
# 1                0.125086
# 2                0.087725
# 3                0.107497
# 4                0.123845
# ..                    ...
# 79               0.071819
# ...

# %%
#plot predicted FVC mean vs true FVC with error bars for std for multimodal model
plt.figure(figsize=(8, 6))
plt.errorbar(
    test_cases_df['Followup FVC Volume L'],
    test_cases_df['Predicted_FVC_MM1_Mean'],
    yerr=test_cases_df['Predicted_FVC_MM1_Std'],
    fmt='o',
    ecolor='lightblue',
    elinewidth=1,
    capsize=0
)
plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
plt.title('Multimodal Model: Predicted FVC vs True FVC with Error Bars')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.legend(['Perfect Prediction', 'Predicted FVC with Std Dev'])
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'multimodal_predicted_vs_true_fvc_with_error_bars.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# plot statistic dependently on diagnosis
diagnosis_stats_mm1 = test_cases_df.groupby('Primary Diagnosis').agg({
    'Followup FVC Volume L': ['mean', 'std'],
    'Predicted_FVC_MM1_Mean': ['mean', 'std'],
    'Predicted_FVC_MM1_Std': ['mean', 'std']
})
#print(diagnosis_stats_mm1)
# plot predicted FVC mean vs true FVC with error bars for std for each diagnosis for multimodal model
diagnoses = test_cases_df['Primary Diagnosis'].unique()
plt.figure(figsize=(8, 6))
for diagnosis in diagnoses:
    subset = test_cases_df[test_cases_df['Primary Diagnosis'] == diagnosis]
    plt.errorbar(
        subset['Followup FVC Volume L'],
        subset['Predicted_FVC_MM1_Mean'],
        yerr=subset['Predicted_FVC_MM1_Std'],
        fmt='o',
        label=diagnosis,
        alpha=0.7
    )
plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
plt.title('Multimodal Model: Predicted FVC vs True FVC with Error Bars by Diagnosis')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.legend(title='Primary Diagnosis')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'multimodal_predicted_vs_true_fvc_by_diagnosis.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# plot statistic dependently on smoking history
smoking_stats_mm1 = test_cases_df.groupby('Smoking History').agg({
    'Followup FVC Volume L': ['mean', 'std'],
    'Predicted_FVC_MM1_Mean': ['mean', 'std'],
    'Predicted_FVC_MM1_Std': ['mean', 'std']
})
#print(smoking_stats_mm1)
# plot predicted FVC mean vs true FVC with error bars for std for each smoking history for multimodal model
smoking_histories = test_cases_df['Smoking History'].unique()
plt.figure(figsize=(8, 6))
for history in smoking_histories:
    subset = test_cases_df[test_cases_df['Smoking History'] == history]
    plt.errorbar(
        subset['Followup FVC Volume L'],
        subset['Predicted_FVC_MM1_Mean'],
        yerr=subset['Predicted_FVC_MM1_Std'],
        fmt='o',
        label=history,
        alpha=0.7
    )
plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
#plt.title('Multimodal Model: Predicted FVC vs True FVC with Error Bars by Smoking History')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.legend(title='Smoking History')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'multimodal_predicted_vs_true_fvc_by_smoking_history.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# stat coulored by delta FVC (column delta fvc already exists in test_cases_df as 'Delta FVC')
plt.figure(figsize=(8, 6))

plt.errorbar(
    test_cases_df['Followup FVC Volume L'],
    test_cases_df['Predicted_FVC_MM1_Mean'],
    yerr=test_cases_df['Predicted_FVC_MM1_Std'],
    fmt='none',
    ecolor='lightgray',
    elinewidth=1,
    alpha=0.7,
    capsize=0,
    zorder=1
)

scatter = plt.scatter(
    test_cases_df['Followup FVC Volume L'],
    test_cases_df['Predicted_FVC_MM1_Mean'],
    c=test_cases_df['Delta FVC'],
    cmap='viridis',
    alpha=0.8,
    edgecolor='white',
    zorder=2
)

plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
#plt.title('Multimodal Model: Predicted FVC vs True FVC Colored by Delta FVC')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.colorbar(scatter, label='Delta FVC [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'mm1_predicted_vs_true_fvc_colored_by_delta_fvc.png'), dpi=300, bbox_inches='tight') 
plt.show()

# %%
# stat coulored by delta FVC (column delta fvc already exists in test_cases_df as 'Delta FVC')
plt.figure(figsize=(8, 6))

plt.errorbar(
    test_cases_df['Followup FVC Volume L'],
    test_cases_df['Predicted_FVC_MM3_Mean'],
    yerr=test_cases_df['Predicted_FVC_MM3_Std'],
    fmt='none',
    ecolor='lightgray',
    elinewidth=1,
    alpha=0.7,
    capsize=0,
    zorder=1
)

scatter = plt.scatter(
    test_cases_df['Followup FVC Volume L'],
    test_cases_df['Predicted_FVC_MM3_Mean'],
    c=test_cases_df['Delta FVC'],
    cmap='viridis',
    alpha=0.8,
    edgecolor='white',
    zorder=2
)

plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
#plt.title('Multimodal Model: Predicted FVC vs True FVC Colored by Delta FVC')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.colorbar(scatter, label='Delta FVC [L]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'mm3_predicted_vs_true_fvc_colored_by_delta_fvc.png'), dpi=300, bbox_inches='tight') 
plt.show()

# %%
# statistics of predicted FVC across folds colored by age
plt.figure(figsize=(8, 6))
scatter = plt.scatter(
    test_cases_df['Followup FVC Volume L'],
    test_cases_df['Predicted_FVC_MM1_Mean'],
    c=test_cases_df['Age'],
    cmap='viridis',
    alpha=0.8,
    edgecolor='white'
)
plt.plot([test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], [test_cases_df['Followup FVC Volume L'].min(), test_cases_df['Followup FVC Volume L'].max()], 'r--')  # line y=x for reference
plt.title('Multimodal Model: Predicted FVC vs True FVC Colored by Age')
plt.xlabel('True FVC [L]')
plt.ylabel('Predicted FVC [L]')
plt.legend(['Perfect Prediction'])
plt.colorbar(scatter, label='Age [years]')
plt.grid(alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'mm3_predicted_vs_true_fvc_colored_by_age.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# patient with strong error in prediction
test_cases_df['Absolute_Error'] = abs(test_cases_df['Followup FVC Volume L'] - test_cases_df['Predicted_FVC_MM1_Mean'])
test_cases_df.sort_values('Absolute_Error', ascending=False)[['PatientID', 'Followup FVC Volume L', 'Predicted_FVC_MM1_Mean', 'Absolute_Error', 'Primary Diagnosis', 'Smoking History', 'Age']]

# first compute error for each fold separately and then compute mean and std of error across folds
for fold in [1,2,3,4,5]:
    test_cases_df[f'Absolute_Error_MM1_f{fold}'] = abs(test_cases_df['Followup FVC Volume L'] - test_cases_df[f'Predicted_FVC_MM1_f{fold}'])    
error_cols = [col for col in test_cases_df.columns if col.startswith('Absolute_Error_MM1')]
test_cases_df['Absolute_Error_MM1_Mean'] = test_cases_df[error_cols].mean(axis=1)
test_cases_df['Absolute_Error_MM1_Std'] = test_cases_df[error_cols].std(axis=1)
test_cases_df[['PatientID', 'Followup FVC Volume L', 'Predicted_FVC_MM1_Mean', 'Absolute_Error_MM1_Mean', 'Absolute_Error_MM1_Std', 'Primary Diagnosis', 'Smoking History', 'Age']].sort_values('Absolute_Error_MM1_Mean', ascending=True)
# Out:
#     PatientID  Followup FVC Volume L  Predicted_FVC_MM1_Mean  \
# 80    1001148                   2.25                2.265966
# 79     687751                   2.39                2.423343
# 65    1001089                   1.59                1.651286
# 75    1001253                   1.49                1.538736
# 22    1000921                   1.85                1.920198
# ..        ...                    ...                     ...
# 31     894746                   4.19                3.589514
# 29    1001201                   2.03                2.635680
# 5      469929                   3.79                3.143900
# 52     374153                   3.18                2.318997
# 18     247524                   3.37                2.092239
#
#     Absolute_Error_MM1_Mean  Absolute_Error_MM1_Std Primary Diagnosis  \
# 80                 0.044206                0.046120               IPF
# 79                 0.064774                0.038421               IPF
# ...

# %%
# same for image-only model
for fold in [1,2,3,4,5]:
    test_cases_df[f'Absolute_Error_Image_f{fold}'] = abs(test_cases_df['Followup FVC Volume L'] - test_cases_df[f'Predicted_FVC_f{fold}'])
error_cols_image = [col for col in test_cases_df.columns if col.startswith('Absolute_Error_Image_f')]
test_cases_df['Absolute_Error_Image_Mean'] = test_cases_df[error_cols_image].mean(axis=1)
test_cases_df['Absolute_Error_Image_Std'] = test_cases_df[error_cols_image].std(axis=1)
test_cases_df[['PatientID', 'Followup FVC Volume L', 'Predicted_FVC_Mean', 'Absolute_Error_Image_Mean', 'Absolute_Error_Image_Std', 'Primary Diagnosis', 'Smoking History', 'Age']].sort_values('Absolute_Error_Image_Mean', ascending=True)
# Out:
#     PatientID  Followup FVC Volume L  Predicted_FVC_Mean  \
# 75    1001253                   1.49            1.545868
# 23    1000988                   1.92            1.903621
# 17    1001310                   1.70            1.740025
# 38    1000901                   2.33            2.345041
# 60     311927                   2.01            1.928273
# ..        ...                    ...                 ...
# 35     910349                   4.23            2.952249
# 54    1000425                   4.00            2.696995
# 10    1000952                   3.69            2.111864
# 30     666234                   4.63            2.966382
# 14    1001268                   3.88            1.959887
#
#     Absolute_Error_Image_Mean  Absolute_Error_Image_Std Primary Diagnosis  \
# 75                   0.060576                  0.056569           CTD-ILD
# 23                   0.067233                  0.062848               IPF
# ...

# %%
## load and plot feature importance for mm1 and mm3 (subplot + transposed/horizontal bars)
f_imp_mm3 = pd.read_csv("Explainability_Multimodal_Permutation_MM-3/multimodal_permutation_importance.csv")
f_imp_mm1 = pd.read_csv("Explainability_Multimodal_Permutation_MM-1/multimodal_permutation_importance.csv")

#filterd top10
f_imp_mm3 = f_imp_mm3.nlargest(10, "Mean_MAE_Increase")
f_imp_mm1 = f_imp_mm1.nlargest(10, "Mean_MAE_Increase")


fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)

for ax, df, title, color in [
    (axes[0], f_imp_mm1, "MM-1", "#1f77b4"),
    (axes[1], f_imp_mm3, "MM-3", "#ff7f0e"),
]:
    df_sorted = df.sort_values("Mean_MAE_Increase", ascending=True)
    ax.barh(
        df_sorted["Feature"],
        df_sorted["Mean_MAE_Increase"],
        xerr=df_sorted["Std_MAE_Increase"],
        color=color,
        alpha=0.7,
        ecolor="gray",
        capsize=3
    )
    ax.set_title(title, fontsize=14)
    ax.set_xlabel("Mean MAE Increase", fontsize=14)
    ax.grid(axis="x", alpha=0.1)

axes[0].set_ylabel("Feature", fontsize=14)
axes[0].set_yticklabels(axes[0].get_yticklabels(), fontsize=13)
axes[1].set_ylabel("", fontsize=14)

#fig.suptitle("Permutation Feature Importance (MAE Increase)", y=1.02)
plt.tight_layout()
plt.savefig(
    os.path.join(FIGURE_DIR, "permutation_feature_importance_mm1_mm3_subplot_transposed.png"),
    dpi=300,
    bbox_inches="tight"
)
plt.show()
# Out:
# /tmp/ipykernel_4010109/2701706198.py:31: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_yticklabels(axes[0].get_yticklabels(), fontsize=13)

# %%
# same one but without the feature Baseline FVC
fig, axes = plt.subplots(1, 2, figsize=(14, 7), sharey=True)
for ax, df, title, color in [
    (axes[0], f_imp_mm1[f_imp_mm1["Feature"] != "Baseline FVC"], "MM-1", "#1f77b4"),
    (axes[1], f_imp_mm3[f_imp_mm3["Feature"] != "Baseline FVC"], "MM-3", "#ff7f0e"),
]:
    df_sorted = df.sort_values("Mean_MAE_Increase", ascending=True)
    ax.barh(
        df_sorted["Feature"],
        df_sorted["Mean_MAE_Increase"],
        xerr=df_sorted["Std_MAE_Increase"],
        color=color,
        alpha=0.7,
        ecolor="gray",
        capsize=3
    )
    ax.set_title(title)
    ax.set_xlabel("Mean MAE Increase")
    ax.grid(axis="x", alpha=0.1)

# %%
# campare contribution of feature CT Image (3D-CNN) in MM-1 and MM-3
ct_importance_mm1 = f_imp_mm1[f_imp_mm1["Feature"] == "CT Image (3D-CNN)"]["Mean_MAE_Increase"].values[0]
ct_importance_mm3 = f_imp_mm3[f_imp_mm3["Feature"] == "CT Image (3D-CNN)"]["Mean_MAE_Increase"].values[0]
print(f"CT Image (3D-CNN) importance - MM-1: {ct_importance_mm1:.4f}, MM-3: {ct_importance_mm3:.4f}")
print(f"Difference in importance of CT Image (3D-CNN) between MM-1 and MM-3: {ct_importance_mm3 - ct_importance_mm1:.4f}")
print(f"Relative increase in importance of CT Image (3D-CNN) from MM-1 to MM-3: {(ct_importance_mm3 - ct_importance_mm1) / ct_importance_mm1 * 100:.2f}%")
# Out:
# CT Image (3D-CNN) importance - MM-1: 0.0112, MM-3: 0.0060
# Difference in importance of CT Image (3D-CNN) between MM-1 and MM-3: -0.0052
# Relative increase in importance of CT Image (3D-CNN) from MM-1 to MM-3: -46.20%

# %%
f_imp_tabular_mlp
# Out:
#                          Feature  Mean_MAE_Increase  Std_MAE_Increase
# 0                   Baseline FVC           0.608043          0.055552
# 1                       Sex_Male           0.149504          0.031540
# 2                     Sex_Female           0.115312          0.024748
# 3      Primary Diagnosis_CTD-ILD           0.089484          0.015760
# 4       Smoking Status_Ex Smoker           0.069435          0.010418
# 5          Primary Diagnosis_IPF           0.063518          0.014541
# 6    Smoking Status_Never Smoker           0.063384          0.011637
# 7                  FEV1 Volume L           0.034376          0.019745
# 8         Primary Diagnosis_UILD           0.025721          0.008516
# 9                            Age           0.021170          0.003968
# 10        Smoking Status_Unknown           0.016174          0.003574
# 11       Primary Diagnosis_Other           0.014752          0.004644
# ...

# %%
## same for tabular only model
f_imp_tabular_mlp = pd.read_csv("Explainability_Tabular_2026-04-14_21-00-17/mlp_permutation_importance.csv")
f_imp_tabular_rf = pd.read_csv("Explainability_Tabular_2026-04-14_21-00-17/rf_permutation_importance.csv")
# # filter top10
# f_imp_tabular_mlp = f_imp_tabular_mlp.nlargest(10, "MLP_Permutation_Mean")
# f_imp_tabular_rf = f_imp_tabular_rf.nlargest(10, "RF_Permutation_Mean")
#rename columns to be the same for both dataframes
f_imp_tabular_mlp = f_imp_tabular_mlp.rename(columns={"MLP_Permutation_Mean": "Mean_MAE_Increase", "MLP_Permutation_Std": "Std_MAE_Increase"})
f_imp_tabular_rf = f_imp_tabular_rf.rename(columns={"RF_Permutation_Mean": "Mean_MAE_Increase", "RF_Permutation_Std": "Std_MAE_Increase"})

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharey=True)
for ax, df, title, color in [
    (axes[0], f_imp_tabular_mlp, "Tabular MLP", "#2ca02c"),
    (axes[1], f_imp_tabular_rf, "Random Forest", "#d62728"),
]:
    df_sorted = df.sort_values('Mean_MAE_Increase', ascending=True)
    ax.barh(
        df_sorted["Feature"],
        df_sorted["Mean_MAE_Increase"],
        xerr=df_sorted["Std_MAE_Increase"],
        color=color,
        alpha=0.7,
        ecolor="gray",
        capsize=3
    )
    ax.set_title(title, fontsize=14)
    ax.set_xlabel("Mean MAE Increase", fontsize=14)
    ax.grid(axis="x", alpha=0.1)
axes[0].set_ylabel("Feature", fontsize=14)
axes[0].set_yticklabels(axes[0].get_yticklabels(), fontsize=13)
axes[1].set_ylabel("", fontsize=14)
#fig.suptitle("Permutation Feature Importance (MAE Increase) - Tabular Models", y=1.02)
plt.tight_layout()
plt.savefig(
    os.path.join(FIGURE_DIR, "permutation_feature_importance_tabular_models_subplot_transposed.png"),
    dpi=300,
    bbox_inches="tight"
)
plt.show()
# Out:
# /tmp/ipykernel_4010109/384553255.py:30: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_yticklabels(axes[0].get_yticklabels(), fontsize=13)

# %%
# plot to compre mm and tabular feature importance, plot of all 4 models together (mm1, mm3, tabular mlp, tabular rf) with different colors for each model and features on y-axis and mean MAE increase on x-axis
# add column Model to each dataframe
f_imp_mm1['Model'] = 'MM-1'
f_imp_mm3['Model'] = 'MM-3'
f_imp_tabular_mlp['Model'] = 'Tabular MLP'
f_imp_tabular_rf['Model'] = 'Random Forest'
# concatenate dataframes
f_imp_all = pd.concat([f_imp_mm1, f_imp_mm3, f_imp_tabular_mlp, f_imp_tabular_rf], ignore_index=True)
# filter top10 features for each model
f_imp_all_top10 = f_imp_all.groupby('Model').apply(lambda x: x.nlargest(10, 'Mean_MAE_Increase')).reset_index(drop=True)
# plot
colour_palette = {
    'MM-1': '#1f77b4',
    'MM-3': "#9dc4d3",
    'Tabular MLP': "#c5ae2d",
    'Random Forest': "#db8640"
}
plt.figure(figsize=(8, 8))
sns.barplot(data=f_imp_all_top10, x='Mean_MAE_Increase', y='Feature', hue='Model', orient='h', palette=colour_palette,)
plt.title('Permutation Feature Importance (Mean MAE Increase) - Tabular vs Multimodal Models', fontsize=14)
plt.xlabel('Mean MAE Increase', fontsize=14)
plt.ylabel('Feature', fontsize=14)
plt.legend(title='Model', fontsize=14)
plt.grid(axis='x', alpha=0.1)
plt.tight_layout()
plt.savefig(os.path.join(FIGURE_DIR, 'permutation_feature_importance_all_models.png'), dpi=300, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_4010109/1943422612.py:10: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   f_imp_all_top10 = f_imp_all.groupby('Model').apply(lambda x: x.nlargest(10, 'Mean_MAE_Increase')).reset_index(drop=True)

# %% [markdown]
# Multimodal
# 247524, 374153 strong error
# 1001405, 1000788 good prediction
# Image only
# 1001268, 1000952 Bad
# 1001253, 1000988 'good'

# %%
voxel = 512*512*400
voxel_2 = 256*256*200
voxel_3 = 384*384*300

print(f"Voxel 512x512x400: {voxel/1e6:.2f} million voxels")
print(f"Voxel 256x256x200: {voxel_2/1e6:.2f} million voxels")
print(f"Voxel 384x384x300: {voxel_3/1e6:.2f} million voxels")
# difference
print(f"Difference between 512x512x400 and 256x256x200: {(voxel - voxel_2)/1e6:.2f} million voxels")
print(f"Difference between 512x512x400 and 384x384x300: {(voxel - voxel_3)/1e6:.2f} million voxels")
print(f"Difference between 384x384x300 and 256x256x200: {(voxel_3 - voxel_2)/1e6:.2f} million voxels")
#procentage difference
print(f"Percentage difference between 512x512x400 and 256x256x200: {(voxel - voxel_2)/voxel*100:.2f}%")
print(f"Percentage difference between 512x512x400 and 384x384x300: {(voxel - voxel_3)/voxel*100:.2f}%")
print(f"Percentage difference between 384x384x300 and 256x256x200: {(voxel_3 - voxel_2)/voxel_3*100:.2f}%")
# Out:
# Voxel 512x512x400: 104.86 million voxels
# Voxel 256x256x200: 13.11 million voxels
# Voxel 384x384x300: 44.24 million voxels
# Difference between 512x512x400 and 256x256x200: 91.75 million voxels
# Difference between 512x512x400 and 384x384x300: 60.62 million voxels
# Difference between 384x384x300 and 256x256x200: 31.13 million voxels
# Percentage difference between 512x512x400 and 256x256x200: 87.50%
# Percentage difference between 512x512x400 and 384x384x300: 57.81%
# Percentage difference between 384x384x300 and 256x256x200: 70.37%
